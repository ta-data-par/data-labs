# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
from scipy.stats import uniform
x = uniform.rvs(size=10)
a = 2
b = 3
randoms  = a + (b-a)*x
print(randoms)
# Out:
# [2.43412326 2.27666345 2.66608453 2.44367045 2.39775425 2.08688912
#  2.96281737 2.18762876 2.06847803 2.76108571]

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
# your code here
def rand_num(bottom,ceiling,count):
    randoms  = []
    val  = bottom + (ceiling-bottom)*uniform.rvs(size = count)
    randoms.append(val)    
    return randoms
#test = rand_num(2,3,10)
f1 = rand_num(10,15,100)
f2 = rand_num(10,60,1000)

# %%
import seaborn as sns
f, axes = plt.subplots(1,2, figsize=(7, 7))
a = rand_num(10,15,100)
sns.distplot(a,bins=10, ax=axes[0], color='orange')
b = rand_num(10,60,1000)
sns.distplot(b,bins=10, ax=axes[1],color='green')
plt.show()

# %% [markdown]
# How are the two distributions different?

# %%
# your answer below

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
# your code here
import numpy as np
def rand_nor(mean,std,count):
    randoms  = []
    val  = np.random.normal(mean, std, count) 
    randoms.append(val)
    return randoms

a=rand_nor(10,1,1000)
b=rand_nor(10,50,1000)

# %%
#plot
f, axes = plt.subplots(1,2, figsize=(7, 7))
sns.distplot(a,bins=10, ax=axes[0],color='r')
sns.distplot(b,bins=10, ax=axes[1])
plt.show()

# %% [markdown]
# How are the two distributions different?

# %%
# your answer below
they look like similar

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
# your code here
import pandas as pd
data = pd.read_csv('vehicles.csv')
data['Fuel Barrels/Year'].hist(bins=50,color='y')

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
# your code here
data['CO2 Emission Grams/Mile'].hist(bins=50,color='c')

# %% [markdown]
# 3. Combined MPG

# %%
# your code here
data['Combined MPG'].hist(bins=50,color='m')

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
# your answer here
'''
the variable Combined MPG seems have a normally distributed. 
Because the distribution is almost symmetric 
'''

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 10.
#
# 1. Use the function to generate two number sequences with the size of 1 and 100.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
# your code here
def rand_exp(count):
    randoms = []
    val = np.random.exponential(.1,count)
    randoms.append(val)
    return randoms
a = rand_exp(1)   
b = rand_exp(100)

# %%
# plot
sns.distplot(b,bins=100)
plt.show()

# %%
sns.distplot(a,bins=100,color='r')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-94-ad8d6d8d366a> in <module>
# ----> 1 sns.distplot(a,bins=100,color='r')
#
# /anaconda3/lib/python3.7/site-packages/seaborn/distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     229     if kde:
#     230         kde_color = kde_kws.pop("color", color)
# --> 231         kdeplot(a, vertical=vertical, ax=ax, color=kde_color, **kde_kws)
#     232         if kde_color != color:
#     233             kde_kws["color"] = kde_color
#
# /anaconda3/lib/python3.7/site-packages/seaborn/distributions.py in kdeplot(data, data2, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     648         data = np.asarray(data)
#     649
# --> 650     if len(data) == 0:
# ...

# %% [markdown]
# How are the two distributions different?

# %%
# your answer here

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
# your answer here
# Hint: This is same as saying P(x<15)
#np.random.exponential(.1,15)
from scipy.stats import expon
data_expon = expon.rvs(scale=.1,size=15)
data_expon
# Out:
# array([0.01623773, 0.01734032, 0.11384892, 0.05074351, 0.0047743 ,
#        0.14431641, 0.1333089 , 0.00946827, 0.03282458, 0.00941166,
#        0.10200563, 0.49668945, 0.15869275, 0.12832518, 0.03942022])

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
# your answer here
data_expon = expon.rvs(scale=.1,size=16)
data_expon
# Out:
# array([0.0164097 , 0.12359259, 0.06479148, 0.27604512, 0.06172273,
#        0.02157859, 0.02001626, 0.05450751, 0.04183459, 0.12665296,
#        0.58107475, 0.01194883, 0.00087905, 0.0921089 , 0.06535731,
#        0.09027524])
