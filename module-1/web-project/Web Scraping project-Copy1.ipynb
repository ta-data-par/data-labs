# %%
import json
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
from pandas.io.json import json_normalize

# %%
url = 'https://www.airbnb.com/api/v2/explore_tabs?_format=for_explore_search_web&_intents=p1&adults=1&auto_ib=false&checkin=2019-09-14&checkout=2019-09-15&children=1&client_session_id=d2278d17-2fb5-4f75-8c4b-e7568e69a294&currency=EUR&current_tab_id=home_tab&experiences_per_grid=20&federated_search_session_id=76d72965-87a1-4d3a-ad12-8dac23f26c3f&fetch_filters=true&guidebooks_per_grid=20&has_zero_guest_treatment=true&infants=1&is_guided_search=true&is_new_cards_experiment=true&is_standard_search=true&items_offset=18&items_per_grid=18&key=d306zoyjsyarp7ifhu67rjxn52tv0t20&last_search_session_id=396bb890-0667-4cb4-b18f-54253e1f2532&locale=en&luxury_pre_launch=true&metadata_only=false&place_id=ChIJD7fiBh9u5kcRYJSMaMOCCwQ&query=Paris&query_understanding_enabled=true&refinement_paths%5B%5D=%2Fhomes&s_tag=V3RB4kXz&satori_version=1.1.9&screen_height=821&screen_size=small&screen_width=705&search_type=pagination&section_offset=7&selected_tab_id=home_tab&show_groupings=true&source=mc_search_bar&supports_for_you_v3=true&timezone_offset=120&toddlers=0&version=1.5.8'

# %%
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
result = response.json()

# %%
result
# Out:
# {'explore_tabs': [{'tab_id': 'home_tab',
#    'tab_name': 'homes',
#    'pagination_metadata': {'has_next_page': True,
#     'items_offset': 36,
#     'section_offset': 6,
#     'search_session_id': 'b0069a06-ef0f-42d0-b195-e7237a36bb38',
#     'has_previous_page': True,
#     'previous_page_items_offset': 0,
#     'previous_page_section_offset': 0},
#    'sections': [{'backend_search_id': '8caf46bf-adb0-4fb1-9647-9541bc38b691',
#      'display_type': 'grid',
#      'experiments_metadata': [],
#      'result_type': 'listings',
#      'search_session_id': 'b0069a06-ef0f-42d0-b195-e7237a36bb38',
#      'section_id': 'b0069a06-ef0f-42d0-b195-e7237a36bb38',
#      'section_type_uid': 'PAGINATED_HOMES',
#      'is_paginated': True,
#      'bankai_section_id': '76',
#      'refinements': [],
#      'listings': [{'listing': {'badges': ['RARE FIND'],
#         'bathroom_label': '1 bath',
#         'bathrooms': 1.0,
#         'bed_label': '1 bed',
#         'bedroom_label': '1 bedroom',
# ...

# %%
flat_data = json_normalize(result)
flat_data
# Out:
#                                         explore_tabs  \
# 0  [{'tab_id': 'home_tab', 'tab_name': 'homes', '...
#
#   metadata.current_refinement_paths metadata.current_tab_id  \
# 0                          [/homes]                home_tab
#
#            metadata.federated_search_id  metadata.federated_search_session_id  \
# 0  1d769cfb-d056-4db2-882c-1ee75ba8091d  76d72965-87a1-4d3a-ad12-8dac23f26c3f
#
#    metadata.geography.accuracy metadata.geography.city  \
# 0                            4                   Paris
#
#   metadata.geography.country metadata.geography.country_code  \
# 0                     France                              FR
#
#   metadata.geography.extended_precision  ... metadata.satori_config.market  \
# 0                                  city  ...                         Paris
#
#    metadata.satori_config.region_id  metadata.satori_config.state_code  \
# 0                                -1
#
#   metadata.satori_config.version metadata.satori_version  \
# ...

# %%
flat_data1 = json_normalize(flat_data.explore_tabs[0])
flat_data1
# Out:
#   experiments_metadata                      home_tab_metadata.breadcrumbs  \
# 0                   []  [{'location_name': 'France', 'canonical_locati...
#
#    home_tab_metadata.filters.eligible_for_left_filters_panel  \
# 0                                              False
#
#   home_tab_metadata.filters.filter_bar_counts.default  \
# 0                                 [0, 0, 0, 0, 0, 0]
#
#   home_tab_metadata.filters.filter_bar_counts.medium  \
# 0                                       [0, 0, 0, 0]
#
#   home_tab_metadata.filters.filter_bar_counts.small  \
# 0                                            [0, 0]
#
#   home_tab_metadata.filters.filter_bar_ordering.default  \
# 0  [date_picker, guest_picker, room_type, price_r...
#
#   home_tab_metadata.filters.filter_bar_ordering.medium  \
# 0  [date_picker, guest_picker, room_type, price_r...
#
#   home_tab_metadata.filters.filter_bar_ordering.small  \
# 0                        [date_picker, guest_picker]
#
# ...

# %%
flat_data2 = json_normalize(flat_data1.sections[0])

# %%
flat_data2
# Out:
#                       backend_search_id bankai_section_id breadcrumbs  \
# 0  8caf46bf-adb0-4fb1-9647-9541bc38b691                76          []
#
#   display_type experiments_metadata hotel_tonight_rooms  is_paginated  \
# 0         grid                   []                  []          True
#
#                                             listings localized_listing_count  \
# 0  [{'listing': {'badges': ['RARE FIND'], 'bathro...                   4,300
#
#   nearby_locations  ... section_component_type  \
# 0               []  ...          LISTINGS_GRID
#
#                              section_id section_metadata.card_layout  \
# 0  b0069a06-ef0f-42d0-b195-e7237a36bb38                      DEFAULT
#
#   section_metadata.has_show_price_cta section_metadata.is_mimicking_paginated  \
# 0                               False                                   False
#
#   section_metadata.see_all_button_outline_color  \
# 0                                       #008489
#
# ...

# %%
flat_data3 = json_normalize(flat_data2.listings[0])

# %%
flat_data3
# Out:
#                                   listing.amenity_ids  listing.avg_rating  \
# 0   [96, 1, 2, 35, 4, 8, 40, 41, 10, 44, 77, 46, 8...                5.00
# 1   [1, 33, 2, 35, 4, 8, 40, 9, 77, 46, 21, 85, 89...                0.00
# 2   [33, 98, 99, 101, 40, 104, 42, 12, 44, 77, 110...                4.35
# 3   [96, 1, 33, 35, 4, 36, 39, 8, 40, 9, 41, 44, 4...                4.62
# 4   [64, 1, 65, 66, 4, 68, 70, 71, 8, 72, 9, 75, 7...                4.88
# 5   [1, 2, 4, 8, 9, 77, 85, 86, 23, 89, 90, 91, 93...                4.46
# 6   [35, 4, 37, 103, 8, 40, 41, 10, 42, 107, 12, 4...                0.00
# 7   [96, 1, 35, 4, 8, 40, 104, 41, 44, 45, 77, 46,...                4.14
# 8   [128, 1, 2, 4, 8, 9, 23, 30, 288, 33, 34, 35, ...                4.76
# 9   [1, 33, 35, 4, 36, 5, 38, 103, 8, 40, 104, 9, ...                4.97
# 10  [1, 2, 3, 4, 8, 10, 77, 89, 90, 91, 93, 30, 94...                4.70
# 11                             [1, 8, 40, 41, 44, 30]                4.33
# ...

# %%
flat_data3.columns
# Out:
# Index(['listing.amenity_ids', 'listing.avg_rating', 'listing.badges',
#        'listing.bathroom_label', 'listing.bathrooms', 'listing.bed_label',
#        'listing.bedroom_label', 'listing.bedrooms', 'listing.beds',
#        'listing.city',
#        ...
#        'pricing_quote.rate_with_service_fee.amount_formatted',
#        'pricing_quote.rate_with_service_fee.currency',
#        'pricing_quote.rate_with_service_fee.is_micros_accuracy',
#        'pricing_quote.should_show_from_label',
#        'pricing_quote.weekly_price_factor', 'verified.badge_secondary_text',
#        'verified.badge_text', 'verified.enabled', 'verified.kicker_badge_type',
#        'verified_card'],
#       dtype='object', length=102)

# %%
flat_data1['pagination_metadata.has_next_page'][0]
# Out:
# True

# %%
a = flat_data1['pagination_metadata.has_next_page'][0]

# %%
df=pd.DataFrame()
import time

# %%
page_nb = 0
while a == True:
    page_nb +=1
    k =18*page_nb
    url = f'https://www.airbnb.com/api/v2/explore_tabs?_format=for_explore_search_web&_intents=p1&adults=1&auto_ib=false&checkin=2019-09-14&checkout=2019-09-15&children=1&client_session_id=d2278d17-2fb5-4f75-8c4b-e7568e69a294&currency=EUR&current_tab_id=home_tab&experiences_per_grid=20&federated_search_session_id=76d72965-87a1-4d3a-ad12-8dac23f26c3f&fetch_filters=true&guidebooks_per_grid=20&has_zero_guest_treatment=true&infants=1&is_guided_search=true&is_new_cards_experiment=true&is_standard_search=true&items_offset={k}&items_per_grid=18&key=d306zoyjsyarp7ifhu67rjxn52tv0t20&last_search_session_id=396bb890-0667-4cb4-b18f-54253e1f2532&locale=en&luxury_pre_launch=true&metadata_only=false&place_id=ChIJD7fiBh9u5kcRYJSMaMOCCwQ&query=Paris&query_understanding_enabled=true&refinement_paths%5B%5D=%2Fhomes&s_tag=V3RB4kXz&satori_version=1.1.9&screen_height=821&screen_size=small&screen_width=705&search_type=pagination&section_offset=7&selected_tab_id=home_tab&show_groupings=true&source=mc_search_bar&supports_for_you_v3=true&timezone_offset=120&toddlers=0&version=1.5.8'
    response= requests.get(url)
    result = response.json()
    flattened_data = json_normalize(result)
    flattened_data = json_normalize(flattened_data.explore_tabs[0])
    a = flattened_data ['pagination_metadata.has_next_page'][0]
    flattened_data = json_normalize(flattened_data.sections[0])
    flattened_data = json_normalize(flattened_data.listings[0])
    flattened_data = flattened_data.set_index('listing.id')
    df = df.append(flattened_data) 
    time.sleep(1)
df
# Out:
#                                           listing.amenity_ids  \
# listing.id
# 37359672            [1, 33, 35, 4, 21, 8, 40, 45, 77, 30, 46]
# 36448160    [96, 1, 2, 35, 4, 8, 40, 41, 10, 44, 77, 46, 8...
# 34291386    [33, 98, 99, 101, 40, 104, 42, 12, 44, 77, 110...
# 36561250    [1, 33, 2, 35, 4, 8, 40, 9, 77, 46, 21, 85, 89...
# 34301609    [96, 1, 33, 35, 4, 36, 39, 8, 40, 9, 41, 44, 4...
# 26353129    [64, 1, 65, 66, 4, 68, 70, 71, 8, 72, 9, 75, 7...
# 37001851    [35, 4, 37, 103, 8, 40, 41, 10, 42, 107, 12, 4...
# 33772517    [1, 2, 4, 8, 9, 77, 85, 86, 23, 89, 90, 91, 93...
# 28996695    [96, 1, 35, 4, 8, 40, 104, 41, 44, 45, 77, 46,...
# 34082068    [128, 1, 2, 4, 8, 9, 23, 30, 288, 33, 34, 35, ...
# 30033301    [1, 33, 35, 4, 36, 5, 38, 103, 8, 40, 104, 9, ...
# 373070      [1, 2, 3, 4, 8, 10, 77, 89, 90, 91, 93, 30, 94...
# 33895212                               [1, 8, 40, 41, 44, 30]
# 26152380    [1, 33, 34, 3, 35, 4, 39, 71, 103, 8, 40, 41, ...
# ...

# %%
response
# Out:
# <Response [429]>

# %%
page_nb
# Out:
# 8

# %%
df.columns.value_counts()
# Out:
# listing.picture_count                                                  1
# listing.localized_city                                                 1
# listing.guest_label                                                    1
# verified.enabled                                                       1
# listing.room_and_property_type                                         1
# pricing_quote.rate_with_service_fee.amount                             1
# listing.star_rating_color                                              1
# pricing_quote.monthly_price_factor                                     1
# verified.kicker_badge_type                                             1
# listing.map_highlight_status                                           1
# pricing_quote.rate.is_micros_accuracy                                  1
# listing.main_section_message.headline                                  1
# listing.min_nights                                                     1
# ...

# %%
df.to_excel('Airbnb.xlsx')

# %%
drop_cols = ['listing.amenity_ids',
'listing.badges',
'listing.bathroom_label',
'listing.formatted_badges',
'listing.host_thumbnail_url',
'listing.host_thumbnail_url_small',
'listing.is_business_travel_ready',
'listing.is_superhost',
'listing.is_business_travel_ready',
'listing.is_new_listing',
'listing.is_superhost',
'listing.kicker_content.text_color',
'listing.lat',
'listing.license',
'listing.lng',
'listing.map_highlight_status',
'listing.picture.preview_encoded_png',
'listing.picture.saturated_a11y_dark_color',
'listing.picture.scrim_color',
'listing.preview_amenity_names',
'listing.preview_encoded_png',
'listing.preview_tags',
'listing.property_type_id',
'listing.scrim_color',
'listing.show_photo_swipe_indicator',
'listing.show_structured_name',
'listing.room_type',
'listing.star_rating_color',
'listing.tier_id',
'listing.user.first_name',
'listing.user.has_profile_pic',
'listing.user.id',
'listing.user.is_superhost',
'listing.user.picture_url',
'listing.user.smart_name',
'listing.user.thumbnail_url',
'listing.wide_kicker_content.text_color',
'pricing_quote.bar_display_price_without_discount.amount',
'pricing_quote.bar_display_price_without_discount.is_micros_accuracy',
'pricing_quote.price.price_items',
'pricing_quote.price.total.amount',
'pricing_quote.price.total.is_micros_accuracy',
'pricing_quote.rate.amount',
'pricing_quote.price_string',
'pricing_quote.rate_type',
'pricing_quote.rate_with_service_fee.amount',
'pricing_quote.rate_with_service_fee.is_micros_accuracy',
'pricing_quote.should_show_from_label',
'verified.badge_text',
'verified.enabled',
'verified.kicker_badge_type',
'verified_card',
'pricing_quote.rate.is_micros_accuracy']

# %%
df1=df.drop(drop_cols, axis=1)

# %%
df1
# Out:
#             listing.avg_rating  listing.bathrooms listing.bed_label  \
# listing.id
# 13867582                  4.93                1.0             1 bed
# 36343914                  0.00                1.0             1 bed
# 31980267                  4.22                1.0             1 bed
# 28832238                  3.86                1.5             1 bed
# 36992698                  0.00                1.0            2 beds
# 35814706                  5.00                1.0             1 bed
# 36849590                  0.00                1.0             1 bed
# 27802102                  5.00                1.0             1 bed
# 7266674                   4.09                1.0             1 bed
# 37121112                  3.00                1.5            0 beds
# 19484263                  4.47                1.0            0 beds
# 37485237                  5.00                1.0             1 bed
# 34173496                  0.00                1.0             1 bed
# ...
