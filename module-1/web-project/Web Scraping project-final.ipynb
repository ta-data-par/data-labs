# %% [markdown]
# # Airbnb Web Scraping

# %%
import json
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
from pandas.io.json import json_normalize

# %% [markdown]
# # Get the information from the customer : Dates, Nb of guests

# %%
import re
pattern= '(2[0-1]\d{2}-(0[1-9]|1[0-2])-(0[1-9]|[12]\d|3[01]))'

# %%
from datetime import date
from datetime import datetime
today = date.today()
d1 = today.strftime("%Y-%m-%d")

while True:
        customer_checkin_date = input('Enter your checkin date with the format YYYY-MM-DD : ')
        if re.fullmatch(pattern,customer_checkin_date)and (d1<customer_checkin_date):
            print(customer_checkin_date)
            break
        else:
            print('Try again with the CORRECT format')

while True:
        customer_checkout_date = input('Enter your checkout date with the format YYYY-MM-DD : ')
        if re.fullmatch(pattern,customer_checkout_date) and (customer_checkin_date <customer_checkout_date) :
            print(customer_checkout_date)
            break
        else:
            print('Try again, it is not the Correct format or it is in the past! ')

while True:
        nb_adults= input('Number of adults : ')
        if((nb_adults.isdigit()) and (int(nb_adults)>0)): 
            print(nb_adults)
            break
        else:
            print('Try again with only numbers')

while True:
    nb_children = input('Please enter the number of children (2yo-12yo): ')
    if nb_children.isdigit():
        break
    else:
        print('Please enter a number: ')
        
while True:
    nb_infants = input('Please enter the number of infants (less than 2yo):')
    if (nb_infants.isdigit()):
        break
    else:
        print('Please enter a number: ')
        
print ('Here is a recap of your information:\n'
       'Dates: from', customer_checkin_date ,'to' , customer_checkout_date,
       '\nAdults:', nb_adults,
       '\nChildren:', nb_children, 
       '\nInfants:', nb_infants)

# %% [markdown]
# # Generate the URL API link with the customer information

# %%
URL API = https://www.airbnb.fr/api/v2/explore_tabs?_format=for_explore_search_web&_intents=p1&adults=<b>{nb_adults}</b>&auto_ib=false&checkin=<b>{customer_checkin_date}</b>&checkout=<b>{customer_checkout_date}</b>&children=<b>{nb_children}</b>&currency=EUR&current_tab_id=home_tab&experiences_per_grid=20&fetch_filters=true&guidebooks_per_grid=20&has_zero_guest_treatment=true&infants=<b>{nb_infants}</b>&is_guided_search=true&is_new_cards_experiment=true&is_standard_search=true&items_offset=18&items_per_grid=18&key=d306zoyjsyarp7ifhu67rjxn52tv0t20&locale=fr&luxury_pre_launch=true&metadata_only=false&place_id=ChIJD7fiBh9u5kcRYJSMaMOCCwQ&query=Paris%2C%20France&query_understanding_enabled=true&refinement_paths%5B%5D=%2Fhomes&s_tag=35-eYpuX&satori_version=1.1.9&screen_height=719&screen_size=medium&screen_width=750&search_type=pagination&section_offset=9&selected_tab_id=home_tab&show_groupings=true&supports_for_you_v3=true&timezone_offset=120&version=1.5.8

# %%
url = f'https://www.airbnb.fr/api/v2/explore_tabs?_format=for_explore_search_web&_intents=p1&adults={nb_adults}&auto_ib=false&checkin={customer_checkin_date}&checkout={customer_checkout_date}&children={nb_children}&currency=EUR&current_tab_id=home_tab&experiences_per_grid=20&fetch_filters=true&guidebooks_per_grid=20&has_zero_guest_treatment=true&infants={nb_infants}&is_guided_search=true&is_new_cards_experiment=true&is_standard_search=true&items_offset=18&items_per_grid=18&key=d306zoyjsyarp7ifhu67rjxn52tv0t20&locale=fr&luxury_pre_launch=true&metadata_only=false&place_id=ChIJD7fiBh9u5kcRYJSMaMOCCwQ&query=Paris%2C%20France&query_understanding_enabled=true&refinement_paths%5B%5D=%2Fhomes&s_tag=35-eYpuX&satori_version=1.1.9&screen_height=719&screen_size=medium&screen_width=750&search_type=pagination&section_offset=9&selected_tab_id=home_tab&show_groupings=true&supports_for_you_v3=true&timezone_offset=120&version=1.5.8'

# %% [markdown]
# # Jsoned the page

# %%
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
result = response.json()

# %%
result
# Out:
# {'explore_tabs': [{'tab_id': 'home_tab',
#    'tab_name': 'homes',
#    'pagination_metadata': {'has_next_page': True,
#     'items_offset': 36,
#     'section_offset': 9,
#     'search_session_id': 'ee6574c4-503c-4dde-b625-995705a73e10',
#     'has_previous_page': True,
#     'previous_page_items_offset': 0,
#     'previous_page_section_offset': 0},
#    'sections': [{'backend_search_id': '74ff98b8-6ee7-4885-85af-ab337352f7d8',
#      'display_type': 'grid',
#      'experiments_metadata': [],
#      'result_type': 'listings',
#      'search_session_id': 'ee6574c4-503c-4dde-b625-995705a73e10',
#      'section_id': 'ee6574c4-503c-4dde-b625-995705a73e10',
#      'section_type_uid': 'PAGINATED_HOMES',
#      'is_paginated': True,
#      'bankai_section_id': '76',
#      'refinements': [],
#      'listings': [{'listing': {'badges': [],
#         'bathroom_label': '1 salle de bain',
#         'bathrooms': 1.0,
#         'bed_label': '2 lits',
#         'bedroom_label': '2 chambres',
#         'bedrooms': 2,
#         'beds': 2,
#         'city': 'Paris',
#         'guest_label': '4 voyageurs',
#         'host_languages': ['en', 'fr', 'es'],
#         'host_thumbnail_url_small': 'https://a0.muscache.com/im/pictures/c188547b-5b71-49b4-ad75-a5b81d9063b6.jpg?aki_policy=profile_small',
#         'host_thumbnail_url': 'https://a0.muscache.com/im/pictures/c188547b-5b71-49b4-ad75-a5b81d9063b6.jpg?aki_policy=profile_x_medium',
#         'id': 12431613,
#         'is_business_travel_ready': False,
#         'is_new_listing': False,
#         'is_superhost': True,
#         'kicker_content': {'messages': ['Logement entier', '2 lits'],
#          'text_color': '#767676'},
#         'lat': 48.89139,
#         'lng': 2.37718,
#         'localized_city': 'Paris',
#         'localized_neighborhood': 'La Villette',
#         'name': 'NEW Calme Ensoleillé Vue Montmartre',
#         'neighborhood': 'La Villette',
#         'person_capacity': 4,
#         'picture_count': 14,
#         'picture_url': 'https://a0.muscache.com/im/pictures/a607defd-a75d-444d-af9a-3798926d2aaa.jpg?aki_policy=large',
#         'picture_urls': ['https://a0.muscache.com/im/pictures/a607defd-a75d-444d-af9a-3798926d2aaa.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/86be8768-9bb9-4491-ad0d-ec88c6ca99bb.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/673e3b41-a0e8-44b0-9d7d-64aa47c405ed.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/d2f1a27b-ca1c-4adf-8741-5b48eb0b6690.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/4c3bf51c-9734-4a25-ac99-1d651e9f6adc.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/0e344516-8b7d-4a70-bd99-ac4694880778.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/85e1830d-de7f-4f2a-886e-852c53476c20.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/4fa32447-4615-4172-8750-26527aec5200.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/2303a6ac-24d1-49d4-92e8-0f6a933fa981.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/1df3ea1d-914b-41d7-82d9-06320a7cf362.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/9c2da75b-c73e-4d72-8b5f-5aaf8b4ee86f.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/49c722b9-da3a-4b61-b140-57c1de57d852.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/6ee00aae-3a93-4c0a-a1a6-36e3d9a0a55c.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/7c710d01-31b0-4870-87f5-74b17116df28.jpg?aki_policy=large'],
#         'picture': {'id': 145211277,
#          'dominant_saturated_color': '#787878',
#          'large_ro': 'https://a0.muscache.com/im/pictures/a607defd-a75d-444d-af9a-3798926d2aaa.jpg?aki_policy=large_ro',
#          'picture': 'https://a0.muscache.com/im/pictures/a607defd-a75d-444d-af9a-3798926d2aaa.jpg?aki_policy=large',
#          'preview_encoded_png': 'iVBORw0KGgoAAAANSUhEUgAAAAUAAAAECAIAAADJUWIXAAAAS0lEQVQIHQFAAL//AYR7bBITGU9TVbKvr8TExgF+dWrx8/hyYWO0wMC5wcIBcHBt0tDUUEhJ6tbP9QcAAVtcWSUiIPL1BgLv1e3q4/3KIPVo6MdtAAAAAElFTkSuQmCC',
#          'saturated_a11y_dark_color': '#787878',
#          'scrim_color': '#2C211D'},
#         'preview_amenities': 'Wi-Fi,Cuisine,Lave-linge',
#         'preview_encoded_png': 'iVBORw0KGgoAAAANSUhEUgAAAAUAAAAECAIAAADJUWIXAAAAS0lEQVQIHQFAAL//AYR7bBITGU9TVbKvr8TExgF+dWrx8/hyYWO0wMC5wcIBcHBt0tDUUEhJ6tbP9QcAAVtcWSUiIPL1BgLv1e3q4/3KIPVo6MdtAAAAAElFTkSuQmCC',
#         'property_type_id': 1,
#         'reviews_count': 117,
#         'room_and_property_type': 'Logement entier',
#         'room_type_category': 'entire_home',
#         'room_type': 'Logement entier',
#         'scrim_color': '#2C211D',
#         'show_structured_name': False,
#         'space_type': 'Logement entier',
#         'star_rating': 5.0,
#         'tier_id': 0,
#         'user': {'first_name': ' ',
#          'has_profile_pic': True,
#          'id': 5024946,
#          'is_superhost': True,
#          'picture_url': 'https://a0.muscache.com/im/pictures/c188547b-5b71-49b4-ad75-a5b81d9063b6.jpg?aki_policy=profile_x_medium',
#          'smart_name': ' ',
#          'thumbnail_url': 'https://a0.muscache.com/im/pictures/c188547b-5b71-49b4-ad75-a5b81d9063b6.jpg?aki_policy=profile_small'},
#         'wide_kicker_content': {'messages': ['Logement entier'],
#          'text_color': '#767676'},
#         'public_address': 'Paris, Île-de-France, France',
#         'amenity_ids': [1,
#          129,
#          3,
#          4,
#          8,
#          77,
#          21,
#          89,
#          90,
#          91,
#          92,
#          93,
#          30,
#          94,
#          31,
#          95,
#          96,
#          33,
#          34,
#          35,
#          37,
#          40,
#          41,
#          44,
#          45,
#          46,
#          47],
#         'preview_amenity_names': ['Wi-Fi', 'Cuisine', 'Lave-linge'],
#         'reviews': [],
#         'star_rating_color': '#008489',
#         'preview_tags': [],
#         'avg_rating': 4.82,
#         'map_highlight_status': 'NO_HIGHLIGHT',
#         'formatted_badges': [],
#         'show_photo_swipe_indicator': True,
#         'license': '7511900455363',
#         'min_nights': 4,
#         'max_nights': 30},
#        'pricing_quote': {'can_instant_book': True,
#         'monthly_price_factor': 0.85,
#         'price': {'localized_title': 'Total',
#          'price_items': [{'localized_title': '89€ x 10 nuits',
#            'price_items': [],
#            'total': {'amount': 892.0,
#             'amount_formatted': '892€',
#             'currency': 'EUR',
#             'is_micros_accuracy': False},
#            'line_item_type': 2,
#            'localized_explanation': 'Le prix moyen à la nuit est arrondi.'},
#           {'localized_title': 'Réduction hebdomadaire de 5%',
#            'price_items': [],
#            'total': {'amount': -45.0,
#             'amount_formatted': '-45€',
#             'currency': 'EUR',
#             'is_micros_accuracy': False},
#            'line_item_type': 7,
#            'localized_explanation': 'Le logement de  offre des réductions hebdomadaire pour les séjours supérieurs à 7 jours.'},
#           {'localized_title': 'Frais de ménage',
#            'price_items': [],
#            'total': {'amount': 55.0,
#             'amount_formatted': '55€',
#             'currency': 'EUR',
#             'is_micros_accuracy': False},
#            'line_item_type': 5,
#            'localized_explanation': "Frais facturés une seule fois par l'hôte pour couvrir les dépenses engagées pour nettoyer son logement."},
#           {'localized_title': 'Frais de service',
#            'price_items': [],
#            'total': {'amount': 140.0,
#             'amount_formatted': '140€',
#             'currency': 'EUR',
#             'is_micros_accuracy': False},
#            'line_item_type': 4,
#            'localized_explanation': "Ces frais participent au fonctionnement de notre plate-forme et nous permettent d'offrir des services comme l'assistance 24h/24 pendant votre voyage. La TVA est incluse."},
#           {'localized_title': 'Taxes de séjour et frais',
#            'price_items': [],
#            'total': {'amount': 53.0,
#             'amount_formatted': '53€',
#             'currency': 'EUR',
#             'is_micros_accuracy': False},
#            'line_item_type': 8,
#            'localized_explanation': ' (Fr - Paris Taxe Additionnelle)\n (Fr - Paris Taxe De Sejour (75056))\n (Fr - Grand Paris Taxe Additionnelle Regionale)'}],
#          'total': {'amount': 1095.0,
#           'amount_formatted': '1 095€',
#           'currency': 'EUR',
#           'is_micros_accuracy': False}},
#         'price_string': '110€',
#         'rate': {'amount': 110.0,
#          'amount_formatted': '110€',
#          'currency': 'EUR',
#          'is_micros_accuracy': False},
#         'rate_type': 'nightly',
#         'rate_with_service_fee': {'amount': 110.0,
#          'amount_formatted': '110€',
#          'currency': 'EUR',
#          'is_micros_accuracy': False},
#         'weekly_price_factor': 0.95,
#         'should_show_from_label': False},
#        'verified': {'enabled': False,
#         'badge_text': 'Plus',
#         'badge_secondary_text': 'Vérifié',
#         'kicker_badge_type': 'filled'},
#        'verified_card': False},
#       {'listing': {'badges': [],
#         'bathroom_label': '1 salle de bain',
#         'bathrooms': 1.0,
#         'bed_label': '3 lits',
#         'bedroom_label': '1 chambre',
#         'bedrooms': 1,
#         'beds': 3,
#         'city': 'Paris',
#         'guest_label': '4 voyageurs',
#         'host_languages': ['fr'],
#         'host_thumbnail_url_small': 'https://a0.muscache.com/im/users/28518560/profile_pic/1425465559/original.jpg?aki_policy=profile_small',
#         'host_thumbnail_url': 'https://a0.muscache.com/im/users/28518560/profile_pic/1425465559/original.jpg?aki_policy=profile_x_medium',
#         'id': 6697074,
#         'is_business_travel_ready': False,
#         'is_new_listing': False,
#         'is_superhost': False,
#         'kicker_content': {'messages': ['Logement entier', '3 lits'],
#          'text_color': '#767676'},
#         'lat': 48.86439,
#         'lng': 2.3699,
#         'localized_city': 'Paris',
#         'localized_neighborhood': '11e arrondissement',
#         'name': 'PARIS CENTRE REPUBLIQUE 2 Pièces',
#         'neighborhood': 'XI Arrondissement',
#         'person_capacity': 4,
#         'picture_count': 10,
#         'picture_url': 'https://a0.muscache.com/im/pictures/ccd1bf78-e1e4-4311-961c-f50a0d1d0228.jpg?aki_policy=large',
#         'picture_urls': ['https://a0.muscache.com/im/pictures/ccd1bf78-e1e4-4311-961c-f50a0d1d0228.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/f2f968c1-5946-4998-bd4e-bab65768ae32.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/84484816/990058be_original.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/84484965/dd39ec6b_original.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/f01e4f92-599f-4835-ac5c-855d74a55a26.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/c2d281fa-3bb5-4fdd-ac05-22a60bb54e75.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/110484a6-d773-48a6-8d54-a86391d1c9c2.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/07599c11-5c0d-4de6-9a08-b8258812e7ff.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/6cd92ad1-6e83-4ca4-a36a-18994665249f.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/f62bedb4-3780-4c43-8b3d-10dfa37896af.jpg?aki_policy=large'],
#         'picture': {'id': 279000192,
#          'dominant_saturated_color': '#1D1814',
#          'large_ro': 'https://a0.muscache.com/im/pictures/ccd1bf78-e1e4-4311-961c-f50a0d1d0228.jpg?aki_policy=large_ro',
#          'picture': 'https://a0.muscache.com/im/pictures/ccd1bf78-e1e4-4311-961c-f50a0d1d0228.jpg?aki_policy=large',
#          'preview_encoded_png': 'iVBORw0KGgoAAAANSUhEUgAAAAUAAAAECAIAAADJUWIXAAAAS0lEQVQIHQFAAL//AbeojTZATvT09wUHB/Lu6QFhV0b2/AgWFhYSExMPDQgBMiofFBcdBwgK/gEA19bVAW5dTu3l5AIMEwQOFN7d2v/eFw7gvLkXAAAAAElFTkSuQmCC',
#          'saturated_a11y_dark_color': '#1D1814',
#          'scrim_color': '#1D1814'},
#         'preview_amenities': 'Wi-Fi,Cuisine,Lave-linge',
#         'preview_encoded_png': 'iVBORw0KGgoAAAANSUhEUgAAAAUAAAAECAIAAADJUWIXAAAAS0lEQVQIHQFAAL//AbeojTZATvT09wUHB/Lu6QFhV0b2/AgWFhYSExMPDQgBMiofFBcdBwgK/gEA19bVAW5dTu3l5AIMEwQOFN7d2v/eFw7gvLkXAAAAAElFTkSuQmCC',
#         'property_type_id': 1,
#         'reviews_count': 82,
#         'room_and_property_type': 'Logement entier',
#         'room_type_category': 'entire_home',
#         'room_type': 'Logement entier',
#         'scrim_color': '#1D1814',
#         'show_structured_name': False,
#         'space_type': 'Logement entier',
#         'star_rating': 4.0,
#         'tier_id': 0,
#         'user': {'first_name': ' ',
#          'has_profile_pic': True,
#          'id': 28518560,
#          'is_superhost': False,
#          'picture_url': 'https://a0.muscache.com/im/users/28518560/profile_pic/1425465559/original.jpg?aki_policy=profile_x_medium',
#          'smart_name': ' ',
#          'thumbnail_url': 'https://a0.muscache.com/im/users/28518560/profile_pic/1425465559/original.jpg?aki_policy=profile_small'},
#         'wide_kicker_content': {'messages': ['Logement entier'],
#          'text_color': '#767676'},
#         'public_address': 'Paris, Île-de-France, France',
#         'amenity_ids': [1,
#          33,
#          129,
#          2,
#          34,
#          3,
#          4,
#          8,
#          40,
#          44,
#          45,
#          77,
#          46,
#          47,
#          28,
#          30,
#          31],
#         'preview_amenity_names': ['Wi-Fi', 'Cuisine', 'Lave-linge'],
#         'star_rating_color': '#008489',
#         'preview_tags': [],
#         'avg_rating': 4.12,
#         'map_highlight_status': 'NO_HIGHLIGHT',
#         'formatted_badges': [],
#         'show_photo_swipe_indicator': True,
#         'min_nights': 4,
#         'max_nights': 28},
#        'pricing_quote': {'can_instant_book': False,
#         'monthly_price_factor': 1.0,
#         'price': {'localized_title': 'Total',
#          'price_items': [{'localized_title': '60€ x 10 nuits',
#            'price_items': [],
#            'total': {'amount': 600.0,
#             'amount_formatted': '600€',
#             'currency': 'EUR',
#             'is_micros_accuracy': False},
#            'line_item_type': 2},
#           {'localized_title': 'Frais de ménage',
#            'price_items': [],
#            'total': {'amount': 50.0,
#             'amount_formatted': '50€',
#             'currency': 'EUR',
#             'is_micros_accuracy': False},
#            'line_item_type': 5,
#            'localized_explanation': "Frais facturés une seule fois par l'hôte pour couvrir les dépenses engagées pour nettoyer son logement."},
#           {'localized_title': 'Frais de service',
#            'price_items': [],
#            'total': {'amount': 101.0,
#             'amount_formatted': '101€',
#             'currency': 'EUR',
#             'is_micros_accuracy': False},
#            'line_item_type': 4,
#            'localized_explanation': "Ces frais participent au fonctionnement de notre plate-forme et nous permettent d'offrir des services comme l'assistance 24h/24 pendant votre voyage. La TVA est incluse."},
#           {'localized_title': 'Taxes de séjour et frais',
#            'price_items': [],
#            'total': {'amount': 38.0,
#             'amount_formatted': '38€',
#             'currency': 'EUR',
#             'is_micros_accuracy': False},
#            'line_item_type': 8,
#            'localized_explanation': ' (Fr - Paris Taxe De Sejour (75056))\n (Fr - Grand Paris Taxe Additionnelle Regionale)\n (Fr - Paris Taxe Additionnelle)'}],
#          'total': {'amount': 789.0,
#           'amount_formatted': '789€',
#           'currency': 'EUR',
#           'is_micros_accuracy': False}},
#         'price_string': '79€',
#         'rate': {'amount': 79.0,
#          'amount_formatted': '79€',
#          'currency': 'EUR',
#          'is_micros_accuracy': False},
#         'rate_type': 'nightly',
#         'rate_with_service_fee': {'amount': 79.0,
#          'amount_formatted': '79€',
#          'currency': 'EUR',
#          'is_micros_accuracy': False},
#         'weekly_price_factor': 1.0,
#         'should_show_from_label': False},
#        'verified': {'enabled': False,
#         'badge_text': 'Plus',
#         'badge_secondary_text': 'Vérifié',
#         'kicker_badge_type': 'filled'},
#        'verified_card': False},
#       {'listing': {'badges': [],
#         'bathroom_label': '1 salle de bain',
#         'bathrooms': 1.0,
#         'bed_label': '2 lits',
#         'bedroom_label': 'Studio',
#         'bedrooms': 0,
#         'beds': 2,
#         'city': 'Paris',
#         'guest_label': '4 voyageurs',
#         'host_languages': [],
#         'host_thumbnail_url_small': 'https://a0.muscache.com/im/pictures/user/1c63befe-64c0-4c42-93e7-b719d87e2f5b.jpg?aki_policy=profile_small',
#         'host_thumbnail_url': 'https://a0.muscache.com/im/pictures/user/1c63befe-64c0-4c42-93e7-b719d87e2f5b.jpg?aki_policy=profile_x_medium',
#         'id': 20682202,
#         'is_business_travel_ready': False,
#         'is_new_listing': False,
#         'is_superhost': False,
#         'kicker_content': {'messages': ['Logement entier', '2 lits'],
#          'text_color': '#767676'},
#         'lat': 48.86636,
#         'lng': 2.34624,
#         'localized_city': 'Paris',
#         'localized_neighborhood': '2e arrondissement',
#         'name': 'Appartement De designer Aménagé Pour 4 personnes',
#         'neighborhood': 'II Arrondissement',
#         'person_capacity': 4,
#         'picture_count': 14,
#         'picture_url': 'https://a0.muscache.com/im/pictures/c393711d-3166-41ff-9437-1653e95cd20e.jpg?aki_policy=large',
#         'picture_urls': ['https://a0.muscache.com/im/pictures/c393711d-3166-41ff-9437-1653e95cd20e.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/f4a946d1-d476-4012-b202-e9ad08faf4ad.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/23f8c795-90b7-49e6-9cb3-aa66aa6736e9.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/7c02c546-c04d-4869-91b1-e200e5564966.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/b794f3a8-0fab-4dab-b98a-38841a6b6d5b.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/058a0c46-7cd2-4740-9076-3f49ba6045df.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/6641700f-703c-4e80-a7e9-3cc1bb67f9e3.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/b0c2a68a-3bc3-4906-a115-1851d80bd392.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/52176d1a-d8f7-4e47-ab74-3f75dff61d9c.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/0d65e168-4606-4ba9-b140-419e72ca0988.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/7f14cc87-85c1-4949-a3cd-eb88f66900fa.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/6cd6b490-0f08-4836-8035-aa3087d67f3b.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/41053aa9-5470-48a3-94dc-eeaf2fb802ae.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/1ee2f54a-109d-4345-ab83-e18d9db97430.jpg?aki_policy=large'],
#         'picture': {'id': 365360456,
#          'dominant_saturated_color': '#840731',
#          'large_ro': 'https://a0.muscache.com/im/pictures/c393711d-3166-41ff-9437-1653e95cd20e.jpg?aki_policy=large_ro',
#          'picture': 'https://a0.muscache.com/im/pictures/c393711d-3166-41ff-9437-1653e95cd20e.jpg?aki_policy=large',
#          'preview_encoded_png': 'iVBORw0KGgoAAAANSUhEUgAAAAUAAAADCAIAAADUVFKvAAAAO0lEQVQIHQEwAM//AbukkAIKEff6APX2993e3wFRRj8sLCouMDENDhDNy8oBZU88JiIcGxoazsPg3+nq+IcUt9RRxAgAAAAASUVORK5CYII=',
#          'saturated_a11y_dark_color': '#840731',
#          'scrim_color': '#282320'},
#         'preview_amenities': 'Hôte : une entreprise,Wi-Fi,Cuisine,Lave-linge',
#         'preview_encoded_png': 'iVBORw0KGgoAAAANSUhEUgAAAAUAAAADCAIAAADUVFKvAAAAO0lEQVQIHQEwAM//AbukkAIKEff6APX2993e3wFRRj8sLCouMDENDhDNy8oBZU88JiIcGxoazsPg3+nq+IcUt9RRxAgAAAAASUVORK5CYII=',
#         'property_type_id': 1,
#         'reviews_count': 89,
#         'room_and_property_type': 'Logement entier',
#         'room_type_category': 'entire_home',
#         'room_type': 'Logement entier',
#         'scrim_color': '#282320',
#         'show_structured_name': False,
#         'space_type': 'Logement entier',
#         'star_rating': 5.0,
#         'tier_id': 0,
#         'user': {'first_name': ' ',
#          'has_profile_pic': True,
#          'id': 148008439,
#          'is_superhost': False,
#          'picture_url': 'https://a0.muscache.com/im/pictures/user/1c63befe-64c0-4c42-93e7-b719d87e2f5b.jpg?aki_policy=profile_x_medium',
#          'smart_name': ' ',
#          'thumbnail_url': 'https://a0.muscache.com/im/pictures/user/1c63befe-64c0-4c42-93e7-b719d87e2f5b.jpg?aki_policy=profile_small'},
#         'wide_kicker_content': {'messages': ['Logement entier'],
#          'text_color': '#767676'},
#         'public_address': 'Paris, Île-de-France, France',
#         'amenity_ids': [1,
#          33,
#          34,
#          35,
#          4,
#          36,
#          39,
#          8,
#          40,
#          72,
#          104,
#          41,
#          10,
#          44,
#          45,
#          77,
#          46,
#          47,
#          51,
#          54,
#          30,
#          31],
#         'preview_amenity_names': ['Hôte : une entreprise',
#          'Wi-Fi',
#          'Cuisine',
#          'Lave-linge'],
#         'reviews': [],
#         'star_rating_color': '#008489',
#         'preview_tags': [],
#         'avg_rating': 4.76,
#         'map_highlight_status': 'NO_HIGHLIGHT',
#         'formatted_badges': [],
#         'show_photo_swipe_indicator': True,
#         'license': '7510201721483',
#         'min_nights': 2,
#         'max_nights': 1125},
#        'pricing_quote': {'can_instant_book': True,
#         'monthly_price_factor': 0.8,
#         'price': {'localized_title': 'Total',
#          'price_items': [{'localized_title': '90€ x 10 nuits',
#            'price_items': [],
#            'total': {'amount': 900.0,
#             'amount_formatted': '900€',
#             'currency': 'EUR',
#             'is_micros_accuracy': False},
#            'line_item_type': 2},
#           {'localized_title': 'Frais de ménage',
#            'price_items': [],
#            'total': {'amount': 75.0,
#             'amount_formatted': '75€',
#             'currency': 'EUR',
#             'is_micros_accuracy': False},
#            'line_item_type': 5,
#            'localized_explanation': "Frais facturés une seule fois par l'hôte pour couvrir les dépenses engagées pour nettoyer son logement."},
#           {'localized_title': 'Frais de service',
#            'price_items': [],
#            'total': {'amount': 151.0,
#             'amount_formatted': '151€',
#             'currency': 'EUR',
#             'is_micros_accuracy': False},
#            'line_item_type': 4,
#            'localized_explanation': "Ces frais participent au fonctionnement de notre plate-forme et nous permettent d'offrir des services comme l'assistance 24h/24 pendant votre voyage. La TVA est incluse."},
#           {'localized_title': 'Taxes de séjour et frais',
#            'price_items': [],
#            'total': {'amount': 56.0,
#             'amount_formatted': '56€',
#             'currency': 'EUR',
#             'is_micros_accuracy': False},
#            'line_item_type': 8,
#            'localized_explanation': ' (Fr - Paris Taxe Additionnelle)\n (Fr - Grand Paris Taxe Additionnelle Regionale)\n (Fr - Paris Taxe De Sejour (75056))'}],
#          'total': {'amount': 1182.0,
#           'amount_formatted': '1 182€',
#           'currency': 'EUR',
#           'is_micros_accuracy': False}},
#         'price_string': '119€',
#         'rate': {'amount': 119.0,
#          'amount_formatted': '119€',
#          'currency': 'EUR',
#          'is_micros_accuracy': False},
#         'rate_type': 'nightly',
#         'rate_with_service_fee': {'amount': 119.0,
#          'amount_formatted': '119€',
#          'currency': 'EUR',
#          'is_micros_accuracy': False},
#         'weekly_price_factor': 1.0,
#         'should_show_from_label': False},
#        'verified': {'enabled': False,
#         'badge_text': 'Plus',
#         'badge_secondary_text': 'Vérifié',
#         'kicker_badge_type': 'filled'},
#        'verified_card': False},
#       {'listing': {'badges': ['PERLE RARE'],
#         'bathroom_label': '1 salle de bain',
#         'bathrooms': 1.0,
#         'bed_label': '2 lits',
#         'bedroom_label': '1 chambre',
#         'bedrooms': 1,
#         'beds': 2,
#         'city': 'Paris',
#         'guest_label': '4 voyageurs',
#         'host_languages': ['en', 'fr'],
#         'host_thumbnail_url_small': 'https://a0.muscache.com/im/pictures/user/658b402a-3419-440d-be8d-a14346a3f908.jpg?aki_policy=profile_small',
#         'host_thumbnail_url': 'https://a0.muscache.com/im/pictures/user/658b402a-3419-440d-be8d-a14346a3f908.jpg?aki_policy=profile_x_medium',
#         'id': 26612229,
#         'is_business_travel_ready': False,
#         'is_new_listing': False,
#         'is_superhost': False,
#         'kicker_content': {'messages': ['Logement entier', '2 lits'],
#          'text_color': '#767676'},
#         'lat': 48.85088,
#         'lng': 2.38875,
#         'localized_city': 'Paris',
#         'localized_neighborhood': 'Nation',
#         'main_section_message': {'headline': 'PERLE RARE',
#          'type': 'occupancy_rate',
#          'body': 'Les réservations pour cette adresse sont fréquentes.'},
#         'name': 'Superbe apt spacieux dans un quartier dynamique',
#         'neighborhood': 'Nation',
#         'person_capacity': 4,
#         'picture_count': 10,
#         'picture_url': 'https://a0.muscache.com/im/pictures/7017d6d9-0e4f-4035-a08c-5b3176da2472.jpg?aki_policy=large',
#         'picture_urls': ['https://a0.muscache.com/im/pictures/7017d6d9-0e4f-4035-a08c-5b3176da2472.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/2a328e82-aeb6-49d0-95f9-8cc86a323838.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/5d21b8f3-0ab1-43cf-8570-b643f76c68a1.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/f32cf6d5-d3f1-44be-bd4e-fbc707fd9caf.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/09417fab-b5ee-4056-a757-88f419e9c68d.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/6df53c89-c5e4-40b0-9b90-e6a06ba658c8.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/62b38331-8f96-4e81-8871-62a52af51765.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/50576ce8-e8e4-4aa5-a276-5717dc390bc8.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/ac514403-b8c5-41fa-bf11-50008aa09ead.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/b8476dfc-2093-44a9-8085-05b160a81e8a.jpg?aki_policy=large'],
#         'picture': {'id': 531709953,
#          'dominant_saturated_color': '#A98C65',
#          'large_ro': 'https://a0.muscache.com/im/pictures/7017d6d9-0e4f-4035-a08c-5b3176da2472.jpg?aki_policy=large_ro',
#          'picture': 'https://a0.muscache.com/im/pictures/7017d6d9-0e4f-4035-a08c-5b3176da2472.jpg?aki_policy=large',
#          'preview_encoded_png': 'iVBORw0KGgoAAAANSUhEUgAAAAUAAAADCAIAAADUVFKvAAAAO0lEQVQIHQEwAM//AcS+tv3+Afbs1/sKJgAHDgG1rqUFBgrK09oQDhUfJCMBlpmcAf8A+PoA4er2HyIdIZIVOo30pTcAAAAASUVORK5CYII=',
#          'saturated_a11y_dark_color': '#A98C65',
#          'scrim_color': '#343339'},
#         'preview_amenities': 'Wi-Fi,Cuisine,Lave-linge',
#         'preview_encoded_png': 'iVBORw0KGgoAAAANSUhEUgAAAAUAAAADCAIAAADUVFKvAAAAO0lEQVQIHQEwAM//AcS+tv3+Afbs1/sKJgAHDgG1rqUFBgrK09oQDhUfJCMBlpmcAf8A+PoA4er2HyIdIZIVOo30pTcAAAAASUVORK5CYII=',
#         'property_type_id': 1,
#         'reviews_count': 92,
#         'room_and_property_type': 'Logement entier',
#         'room_type_category': 'entire_home',
#         'room_type': 'Logement entier',
#         'scrim_color': '#343339',
#         'show_structured_name': False,
#         'space_type': 'Logement entier',
#         'star_rating': 4.0,
#         'tier_id': 0,
#         'user': {'first_name': ' ',
#          'has_profile_pic': True,
#          'id': 199700933,
#          'is_superhost': False,
#          'picture_url': 'https://a0.muscache.com/im/pictures/user/658b402a-3419-440d-be8d-a14346a3f908.jpg?aki_policy=profile_x_medium',
#          'smart_name': ' ',
#          'thumbnail_url': 'https://a0.muscache.com/im/pictures/user/658b402a-3419-440d-be8d-a14346a3f908.jpg?aki_policy=profile_small'},
#         'wide_kicker_content': {'messages': ['Logement entier'],
#          'text_color': '#767676'},
#         'public_address': 'Paris, Île-de-France, France',
#         'amenity_ids': [1,
#          33,
#          35,
#          4,
#          36,
#          8,
#          40,
#          41,
#          44,
#          45,
#          77,
#          47,
#          85,
#          56,
#          90,
#          91,
#          92,
#          93,
#          30,
#          95],
#         'preview_amenity_names': ['Wi-Fi', 'Cuisine', 'Lave-linge'],
#         'star_rating_color': '#008489',
#         'preview_tags': [],
#         'avg_rating': 4.01,
#         'map_highlight_status': 'NO_HIGHLIGHT',
#         'formatted_badges': [{'text': 'PERLE RARE'}],
#         'show_photo_swipe_indicator': True,
#         'license': '7511101656207',
#         'min_nights': 1,
#         'max_nights': 1125},
#        'pricing_quote': {'can_instant_book': False,
#         'monthly_price_factor': 1.0,
#         'price': {'localized_title': 'Total',
#          'price_items': [{'localized_title': '62€ x 10 nuits',
#            'price_items': [],
#            'total': {'amount': 623.0,
#             'amount_formatted': '623€',
#             'currency': 'EUR',
#             'is_micros_accuracy': False},
#            'line_item_type': 2,
#            'localized_explanation': 'Le prix moyen à la nuit est arrondi.'},
#           {'localized_title': 'Frais de ménage',
#            'price_items': [],
#            'total': {'amount': 60.0,
#             'amount_formatted': '60€',
#             'currency': 'EUR',
#             'is_micros_accuracy': False},
#            'line_item_type': 5,
#            'localized_explanation': "Frais facturés une seule fois par l'hôte pour couvrir les dépenses engagées pour nettoyer son logement."},
#           {'localized_title': 'Frais de service',
#            'price_items': [],
#            'total': {'amount': 106.0,
#             'amount_formatted': '106€',
#             'currency': 'EUR',
#             'is_micros_accuracy': False},
#            'line_item_type': 4,
#            'localized_explanation': "Ces frais participent au fonctionnement de notre plate-forme et nous permettent d'offrir des services comme l'assistance 24h/24 pendant votre voyage. La TVA est incluse."},
#           {'localized_title': 'Taxes de séjour et frais',
#            'price_items': [],
#            'total': {'amount': 39.0,
#             'amount_formatted': '39€',
#             'currency': 'EUR',
#             'is_micros_accuracy': False},
#            'line_item_type': 8,
#            'localized_explanation': ' (Fr - Paris Taxe De Sejour (75056))\n (Fr - Grand Paris Taxe Additionnelle Regionale)\n (Fr - Paris Taxe Additionnelle)'}],
#          'total': {'amount': 828.0,
#           'amount_formatted': '828€',
#           'currency': 'EUR',
#           'is_micros_accuracy': False}},
#         'price_string': '83€',
#         'rate': {'amount': 83.0,
#          'amount_formatted': '83€',
#          'currency': 'EUR',
#          'is_micros_accuracy': False},
#         'rate_type': 'nightly',
#         'rate_with_service_fee': {'amount': 83.0,
#          'amount_formatted': '83€',
#          'currency': 'EUR',
#          'is_micros_accuracy': False},
#         'weekly_price_factor': 1.0,
#         'should_show_from_label': False},
#        'verified': {'enabled': False,
#         'badge_text': 'Plus',
#         'badge_secondary_text': 'Vérifié',
#         'kicker_badge_type': 'filled'},
#        'verified_card': False},
#       {'listing': {'badges': ['PERLE RARE'],
#         'bathroom_label': '1 salle de bain',
#         'bathrooms': 1.0,
#         'bed_label': '3 lits',
#         'bedroom_label': '1 chambre',
#         'bedrooms': 1,
#         'beds': 3,
#         'city': 'Paris',
#         'guest_label': '3 voyageurs',
#         'host_languages': ['ar', 'nl', 'en', 'fr', 'es'],
#         'host_thumbnail_url_small': 'https://a0.muscache.com/im/users/12347031/profile_pic/1398705426/original.jpg?aki_policy=profile_small',
#         'host_thumbnail_url': 'https://a0.muscache.com/im/users/12347031/profile_pic/1398705426/original.jpg?aki_policy=profile_x_medium',
#         'id': 5654383,
#         'is_business_travel_ready': False,
#         'is_new_listing': False,
#         'is_superhost': False,
#         'kicker_content': {'messages': ['Logement entier', '3 lits'],
#          'text_color': '#767676'},
#         'lat': 48.85691,
#         'lng': 2.35295,
#         'localized_city': 'Paris',
#         'localized_neighborhood': '4e arrondissement',
#         'main_section_message': {'headline': 'PERLE RARE',
#          'type': 'occupancy_rate',
#          'body': 'Les réservations pour cette adresse sont fréquentes.'},
#         'name': 'Hidden Treasure in Heart of Paris',
#         'neighborhood': 'IV Arrondissement',
#         'person_capacity': 3,
#         'picture_count': 16,
#         'picture_url': 'https://a0.muscache.com/im/pictures/104585129/1b87f9b7_original.jpg?aki_policy=large',
#         'picture_urls': ['https://a0.muscache.com/im/pictures/104585129/1b87f9b7_original.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/104585146/aacb8d0c_original.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/104585157/0da88b0e_original.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/104585173/6d44f058_original.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/104585184/8c2103ae_original.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/104585190/68a984e2_original.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/104585200/641b9ccd_original.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/104585205/758342b5_original.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/104585214/91092275_original.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/104585222/305fad9a_original.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/104585231/10d3f6d3_original.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/104585245/86987c83_original.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/104585263/c3eeea5d_original.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/104585273/4a48d27f_original.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/104585288/03228c71_original.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/104585298/0c6b7959_original.jpg?aki_policy=large'],
#         'picture': {'id': 80899017,
#          'dominant_saturated_color': '#787878',
#          'large_ro': 'https://a0.muscache.com/im/pictures/104585129/1b87f9b7_original.jpg?aki_policy=large_ro',
#          'picture': 'https://a0.muscache.com/im/pictures/104585129/1b87f9b7_original.jpg?aki_policy=large',
#          'preview_encoded_png': 'iVBORw0KGgoAAAANSUhEUgAAAAUAAAADCAIAAADUVFKvAAAAO0lEQVQIHQEwAM//AdLIvgwMCwL99PPw7/f5/AGLiYgF//r59OosKCQVGiABZmZoLCkl9+XW69zSGicvfZIY0aFj9JcAAAAASUVORK5CYII=',
#          'saturated_a11y_dark_color': '#787878',
#          'scrim_color': '#2A2521'},
#         'preview_amenities': 'Wi-Fi,Cuisine,Lave-linge',
#         'preview_encoded_png': 'iVBORw0KGgoAAAANSUhEUgAAAAUAAAADCAIAAADUVFKvAAAAO0lEQVQIHQEwAM//AdLIvgwMCwL99PPw7/f5/AGLiYgF//r59OosKCQVGiABZmZoLCkl9+XW69zSGicvfZIY0aFj9JcAAAAASUVORK5CYII=',
#         'property_type_id': 1,
#         'reviews_count': 139,
#         'room_and_property_type': 'Logement entier',
#         'room_type_category': 'entire_home',
#         'room_type': 'Logement entier',
#         'scrim_color': '#2A2521',
#         'show_structured_name': False,
#         'space_type': 'Logement entier',
#         'star_rating': 4.5,
#         'tier_id': 0,
#         'user': {'first_name': ' ',
#          'has_profile_pic': True,
#          'id': 12347031,
#          'is_superhost': False,
#          'picture_url': 'https://a0.muscache.com/im/users/12347031/profile_pic/1398705426/original.jpg?aki_policy=profile_x_medium',
#          'smart_name': ' ',
#          'thumbnail_url': 'https://a0.muscache.com/im/users/12347031/profile_pic/1398705426/original.jpg?aki_policy=profile_small'},
#         'wide_kicker_content': {'messages': ['Logement entier'],
#          'text_color': '#767676'},
#         'public_address': 'Paris, Île-de-France, France',
#         'amenity_ids': [1,
#          33,
#          34,
#          3,
#          35,
#          4,
#          5,
#          39,
#          8,
#          40,
#          44,
#          45,
#          77,
#          21,
#          85,
#          30,
#          31],
#         'preview_amenity_names': ['Wi-Fi', 'Cuisine', 'Lave-linge'],
#         'reviews': [],
#         'star_rating_color': '#008489',
#         'preview_tags': [],
#         'avg_rating': 4.41,
#         'map_highlight_status': 'NO_HIGHLIGHT',
#         'formatted_badges': [{'text': 'PERLE RARE'}],
#         'show_photo_swipe_indicator': True,
#         'license': '7510102308460',
#         'min_nights': 2,
#         'max_nights': 30},
#        'pricing_quote': {'can_instant_book': False,
#         'monthly_price_factor': 0.7,
#         'price': {'localized_title': 'Total',
#          'price_items': [{'localized_title': '100€ x 10 nuits',
#            'price_items': [],
#            'total': {'amount': 1000.0,
#             'amount_formatted': '1 000€',
#             'currency': 'EUR',
#             'is_micros_accuracy': False},
#            'line_item_type': 2},
#           {'localized_title': 'Réduction hebdomadaire de 15%',
#            'price_items': [],
#            'total': {'amount': -150.0,
#             'amount_formatted': '-150€',
#             'currency': 'EUR',
#             'is_micros_accuracy': False},
#            'line_item_type': 7,
#            'localized_explanation': 'Le logement de  offre des réductions hebdomadaire pour les séjours supérieurs à 7 jours.'},
#           {'localized_title': 'Frais de ménage',
#            'price_items': [],
#            'total': {'amount': 35.0,
#             'amount_formatted': '35€',
#             'currency': 'EUR',
#             'is_micros_accuracy': False},
#            'line_item_type': 5,
#            'localized_explanation': "Frais facturés une seule fois par l'hôte pour couvrir les dépenses engagées pour nettoyer son logement."},
#           {'localized_title': 'Frais de service',
#            'price_items': [],
#            'total': {'amount': 137.0,
#             'amount_formatted': '137€',
#             'currency': 'EUR',
#             'is_micros_accuracy': False},
#            'line_item_type': 4,
#            'localized_explanation': "Ces frais participent au fonctionnement de notre plate-forme et nous permettent d'offrir des services comme l'assistance 24h/24 pendant votre voyage. La TVA est incluse."},
#           {'localized_title': 'Taxes de séjour et frais',
#            'price_items': [],
#            'total': {'amount': 53.0,
#             'amount_formatted': '53€',
#             'currency': 'EUR',
#             'is_micros_accuracy': False},
#            'line_item_type': 8,
#            'localized_explanation': ' (Fr - Paris Taxe Additionnelle)\n (Fr - Grand Paris Taxe Additionnelle Regionale)\n (Fr - Paris Taxe De Sejour (75056))'}],
#          'total': {'amount': 1075.0,
#           'amount_formatted': '1 075€',
#           'currency': 'EUR',
#           'is_micros_accuracy': False}},
#         'price_string': '108€',
#         'rate': {'amount': 108.0,
#          'amount_formatted': '108€',
#          'currency': 'EUR',
#          'is_micros_accuracy': False},
#         'rate_type': 'nightly',
#         'rate_with_service_fee': {'amount': 108.0,
#          'amount_formatted': '108€',
#          'currency': 'EUR',
#          'is_micros_accuracy': False},
#         'weekly_price_factor': 0.85,
#         'should_show_from_label': False,
#         'bar_display_price_without_discount': {'amount': 123.0,
#          'amount_formatted': '123€',
#          'currency': 'EUR',
#          'is_micros_accuracy': False},
#         'price_drop_disclaimer': "Le prix à la nuit de ce logement est réduit de 12\xa0%. Consultez l'annonce pour plus de détails."},
#        'verified': {'enabled': False,
#         'badge_text': 'Plus',
#         'badge_secondary_text': 'Vérifié',
#         'kicker_badge_type': 'filled'},
#        'verified_card': False},
#       {'listing': {'badges': [],
#         'bathroom_label': '1,5\xa0salle de bain',
#         'bathrooms': 1.5,
#         'bed_label': '2 lits',
#         'bedroom_label': '1 chambre',
#         'bedrooms': 1,
#         'beds': 2,
#         'city': 'Paris',
#         'guest_label': '4 voyageurs',
#         'host_languages': ['en'],
#         'host_thumbnail_url_small': 'https://a0.muscache.com/im/pictures/user/567368a5-0857-4aa0-8e42-49a26615599a.jpg?aki_policy=profile_small',
#         'host_thumbnail_url': 'https://a0.muscache.com/im/pictures/user/567368a5-0857-4aa0-8e42-49a26615599a.jpg?aki_policy=profile_x_medium',
#         'id': 33082947,
#         'is_business_travel_ready': False,
#         'is_new_listing': False,
#         'is_superhost': True,
#         'kicker_content': {'messages': ['Appartement avec services hôteliers entier',
#           '2 lits'],
#          'text_color': '#767676'},
#         'lat': 48.83722,
#         'lng': 2.3831,
#         'localized_city': 'Paris',
#         'localized_neighborhood': '12e arrondissement',
#         'name': 'Charming & cozy apartment for a delightful stay 4p',
#         'neighborhood': 'XII Arrondissement',
#         'person_capacity': 4,
#         'picture_count': 18,
#         'picture_url': 'https://a0.muscache.com/im/pictures/b6e9fa62-de87-4287-82e2-687f25b9c078.jpg?aki_policy=large',
#         'picture_urls': ['https://a0.muscache.com/im/pictures/b6e9fa62-de87-4287-82e2-687f25b9c078.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/9a94e2d0-3f8b-42e0-8ace-85edc2ea1af2.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/6c4daf3e-704d-43ab-9f4e-aae665aac7c7.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/352ee6fc-fee7-4390-a2a8-4d3fc7c71634.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/e4158830-bb27-4c82-b69a-9cf27a973d00.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/e3083158-baf0-4d50-bc0e-a240422e490b.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/60cf22e5-a2f0-49c4-be73-0df18f98e0d6.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/7468ff1a-baf4-4bce-8b78-40666d1c1a45.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/8ba614ee-ff09-49df-b3f3-f3d9e8648383.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/fc4d7c2b-e5dc-40a2-90fa-ac42b90ccd88.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/17142f30-d649-4a12-9fc4-2236ebf017d0.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/c2379bcf-0321-4ee7-b932-2067fc5c2e3a.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/aebaf554-ec4b-4d79-b57e-9e8872346e2b.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/cbfc33cc-4333-4e5c-92f0-542b28fe93bf.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/964769bc-9aa8-4c03-956a-6d88b9be4600.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/fdb83ab3-d91d-4ff8-bb85-3cdee2c7fac0.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/ec314361-c4f7-4edd-8dd8-63c67cac43ac.jpg?aki_policy=large',
#          'https://a0.muscache.com/im/pictures/91f19417-73f7-48aa-9690-84f5f4896a1a.jpg?aki_policy=large'],
#         'picture': {'id': 701325015,
#          'dominant_saturated_color': '#D18767',
#          'large_ro': 'https://a0.muscache.com/im/pictures/b6e9fa62-de87-4287-82e2-687f25b9c078.jpg?aki_policy=large_ro',
#          'picture': 'https://a0.muscache.com/im/pictures/b6e9fa62-de87-4287-82e2-687f25b9c078.jpg?aki_policy=large',
#          'preview_encoded_png': 'iVBORw0KGgoAAAANSUhEUgAAAAUAAAADCAIAAADUVFKvAAAAO0lEQVQIHQEwAM//Ad3VzBEVFgH///X08vTy8gHKxL0lJiXk39vZ2tffz9ABp52XRUhH2tjU8evk29ze0rUfW/6btLUAAAAASUVORK5CYII=',
#          'saturated_a11y_dark_color': '#D18767',
#          'scrim_color': '#312C26'},
#         'preview_amenities': 'Wi-Fi,Cuisine',
#         'preview_encoded_png': 'iVBORw0KGgoAAAANSUhEUgAAAAUAAAADCAIAAADUVFKvAAAAO0lEQVQIHQEwAM//Ad3VzBEVFgH///X08vTy8gHKxL0lJiXk39vZ2tffz9ABp52XRUhH2tjU8evk29ze0rUfW/6btLUAAAAASUVORK5CYII=',
#         'property_type_id': 47,
#         'reviews_count': 37,
#         'room_and_property_type': 'Appartement avec services hôteliers entier',
#         'room_type_category': 'entire_home',
#         'room_type': 'Logement entier',
#         'scrim_color': '#312C26',
#         'show_structured_name': False,
#         'space_type': 'Appartement avec services hôteliers entier',
#         'star_rating': 4.5,
#         'tier_id': 0,
#         'user': {'first_name': ' ',
#          'has_profile_pic': True,
#          'id': 245768196,
#          'is_superhost': True,
#          'picture_url': 'https://a0.muscache.com/im/pictures/user/567368a5-0857-4aa0-8e42-49a26615599a.jpg?aki_policy=profile_x_medium',
#          'smart_name': ' ',
#          'thumbnail_url': 'https://a0.muscache.com/im/pictures/user/567368a5-0857-4aa0-8e42-49a26615599a.jpg?aki_policy=profile_small'},
#         'wide_kicker_content': {'messages': ['Appartement avec services hôteliers entier'],
#          'text_color': '#767676'},
#         'public_address': 'Paris, Île-de-France, France',
#         'amenity_ids': [1,
#          35,
#          4,
#          8,
#          40,
#          72,
#          41,
#          42,
#          44,
#          45,
#          77,
#          46,
#          51,
#          85,
#          54,
#          57,
#          89,
#          90,
#          91,
#          93,
#          30,
#          94],
#         'preview_amenity_names': ['Wi-Fi', 'Cuisine'],
#         'reviews': [],
#         'star_rating_color': '#008489',
#         'preview_tags': [],
#         'avg_rating': 4.7,
#         'map_highlight_status': 'NO_HIGHLIGHT',
#         'formatted_badges': [],
#         'show_photo_swipe_indicator': True,
#         'license': '7511202709025',
#         'min_nights': 1,
#         'max_nights': 60},
#        'pricing_quote': {'can_instant_book': True,
#         'monthly_price_factor': 0.75,
#         'price': {'localized_title': 'Total',
#          'price_items': [{'localized_title': '79€ x 10 nuits',
#            'price_items': [],
#            'total': {'amount': 791.0,
#             'amount_formatted': '791€',
#             'currency': 'EUR',
#             'is_micros_accuracy': False},
#            'line_item_type': 2,
#            'localized_explanation': 'Le prix moyen à la nuit est arrondi.'},
#           {'localized_title': 'Réduction hebdomadaire de 15%',
#            'price_items': [],
#            'total': {'amount': -119.0,
#             'amount_formatted': '-119€',
#             'currency': 'EUR',
#             'is_micros_accuracy': False},
#            'line_item_type': 7,
#            'localized_explanation': 'Le logement de  offre des réductions hebdomadaire pour les séjours supérieurs à 7 jours.'},
#           {'localized_title': 'Frais de ménage',
#            'price_items': [],
#            'total': {'amount': 65.0,
#             'amount_formatted': '65€',
#             'currency': 'EUR',
#             'is_micros_accuracy': False},
#            'line_item_type': 5,
#            'localized_explanation': "Frais facturés une seule fois par l'hôte pour couvrir les dépenses engagées pour nettoyer son logement."},
#           {'localized_title': 'Frais de service',
#            'price_items': [],
#            'total': {'amount': 114.0,
#             'amount_formatted': '114€',
#             'currency': 'EUR',
#             'is_micros_accuracy': False},
#            'line_item_type': 4,
#            'localized_explanation': "Ces frais participent au fonctionnement de notre plate-forme et nous permettent d'offrir des services comme l'assistance 24h/24 pendant votre voyage. La TVA est incluse."},
#           {'localized_title': 'Taxes de séjour et frais',
#            'price_items': [],
#            'total': {'amount': 30.0,
#             'amount_formatted': '30€',
#             'currency': 'EUR',
# ...
#          'title': 'Opéra - Grands Boulevards',
#          'params': [{'key': 'neighborhood_ids',
#            'value': 2453,
#            'delete': False,
#            'invisible_to_user': False,
#            'value_type': 'array'}],
#          'sub_type': 'NEIGHBORHOOD',
#          'states': []}],
#        'selected': False,
#        'title': 'Quartiers',
#        'filter_section_id': 'neighborhoods',
#        'expand_text': 'Afficher tous les quartiers',
#        'collapse_text': 'Fermer les quartiers',
#        'bar_items': [],
#        'subsections': [],
#        'experiments_metadata': [],
#        'collapse_subtitle': 'Porte de Clignancourt, +62 autres',
#        'collapse_selected_subtitles': []},
#       {'items': [{'selected': False,
#          'type': 'checkbox',
#          'title': 'English',
#          'params': [{'key': 'languages',
#            'value': 1,
#            'delete': False,
#            'invisible_to_user': False,
#            'value_type': 'array'}],
#          'sub_type': 'HOST_LANGUAGE',
#          'states': []},
#         {'selected': False,
#          'type': 'checkbox',
#          'title': 'Français',
#          'params': [{'key': 'languages',
#            'value': 2,
#            'delete': False,
#            'invisible_to_user': False,
#            'value_type': 'array'}],
#          'sub_type': 'HOST_LANGUAGE',
#          'states': []},
#         {'selected': False,
#          'type': 'checkbox',
#          'title': 'Deutsch',
#          'params': [{'key': 'languages',
#            'value': 4,
#            'delete': False,
#            'invisible_to_user': False,
#            'value_type': 'array'}],
#          'sub_type': 'HOST_LANGUAGE',
#          'states': []},
#         {'selected': False,
#          'type': 'checkbox',
#          'title': '日本語',
#          'params': [{'key': 'languages',
#            'value': 8,
#            'delete': False,
#            'invisible_to_user': False,
#            'value_type': 'array'}],
#          'sub_type': 'HOST_LANGUAGE',
#          'states': []},
#         {'selected': False,
#          'type': 'checkbox',
#          'title': 'Italiano',
#          'params': [{'key': 'languages',
#            'value': 16,
#            'delete': False,
#            'invisible_to_user': False,
#            'value_type': 'array'}],
#          'sub_type': 'HOST_LANGUAGE',
#          'states': []},
#         {'selected': False,
#          'type': 'checkbox',
#          'title': 'Русский',
#          'params': [{'key': 'languages',
#            'value': 32,
#            'delete': False,
#            'invisible_to_user': False,
#            'value_type': 'array'}],
#          'sub_type': 'HOST_LANGUAGE',
#          'states': []},
#         {'selected': False,
#          'type': 'checkbox',
#          'title': 'Español',
#          'params': [{'key': 'languages',
#            'value': 64,
#            'delete': False,
#            'invisible_to_user': False,
#            'value_type': 'array'}],
#          'sub_type': 'HOST_LANGUAGE',
#          'states': []},
#         {'selected': False,
#          'type': 'checkbox',
#          'title': '中文 (简体)',
#          'params': [{'key': 'languages',
#            'value': 128,
#            'delete': False,
#            'invisible_to_user': False,
#            'value_type': 'array'}],
#          'sub_type': 'HOST_LANGUAGE',
#          'states': []},
#         {'selected': False,
#          'type': 'checkbox',
#          'title': 'العربية',
#          'params': [{'key': 'languages',
#            'value': 256,
#            'delete': False,
#            'invisible_to_user': False,
#            'value_type': 'array'}],
#          'sub_type': 'HOST_LANGUAGE',
#          'states': []},
#         {'selected': False,
#          'type': 'checkbox',
#          'title': 'हिन्दी',
#          'params': [{'key': 'languages',
#            'value': 512,
#            'delete': False,
#            'invisible_to_user': False,
#            'value_type': 'array'}],
#          'sub_type': 'HOST_LANGUAGE',
#          'states': []},
#         {'selected': False,
#          'type': 'checkbox',
#          'title': 'Português',
#          'params': [{'key': 'languages',
#            'value': 1024,
#            'delete': False,
#            'invisible_to_user': False,
#            'value_type': 'array'}],
#          'sub_type': 'HOST_LANGUAGE',
#          'states': []},
#         {'selected': False,
#          'type': 'checkbox',
#          'title': 'Türkçe',
#          'params': [{'key': 'languages',
#            'value': 2048,
#            'delete': False,
#            'invisible_to_user': False,
#            'value_type': 'array'}],
#          'sub_type': 'HOST_LANGUAGE',
#          'states': []},
#         {'selected': False,
#          'type': 'checkbox',
#          'title': 'Bahasa',
#          'params': [{'key': 'languages',
#            'value': 4096,
#            'delete': False,
#            'invisible_to_user': False,
#            'value_type': 'array'}],
#          'sub_type': 'HOST_LANGUAGE',
#          'states': []},
#         {'selected': False,
#          'type': 'checkbox',
#          'title': 'Nederlands',
#          'params': [{'key': 'languages',
#            'value': 8192,
#            'delete': False,
#            'invisible_to_user': False,
#            'value_type': 'array'}],
#          'sub_type': 'HOST_LANGUAGE',
#          'states': []},
#         {'selected': False,
#          'type': 'checkbox',
#          'title': '한국어',
#          'params': [{'key': 'languages',
#            'value': 16384,
#            'delete': False,
#            'invisible_to_user': False,
#            'value_type': 'array'}],
#          'sub_type': 'HOST_LANGUAGE',
#          'states': []},
#         {'selected': False,
#          'type': 'checkbox',
#          'title': 'বাংলা',
#          'params': [{'key': 'languages',
#            'value': 32768,
#            'delete': False,
#            'invisible_to_user': False,
#            'value_type': 'array'}],
#          'sub_type': 'HOST_LANGUAGE',
#          'states': []},
#         {'selected': False,
#          'type': 'checkbox',
#          'title': 'ภาษาไทย',
#          'params': [{'key': 'languages',
#            'value': 65536,
#            'delete': False,
#            'invisible_to_user': False,
#            'value_type': 'array'}],
#          'sub_type': 'HOST_LANGUAGE',
#          'states': []},
#         {'selected': False,
#          'type': 'checkbox',
#          'title': 'ਪੰਜਾਬੀ',
#          'params': [{'key': 'languages',
#            'value': 131072,
#            'delete': False,
#            'invisible_to_user': False,
#            'value_type': 'array'}],
#          'sub_type': 'HOST_LANGUAGE',
#          'states': []},
#         {'selected': False,
#          'type': 'checkbox',
#          'title': 'Eλληνικά',
#          'params': [{'key': 'languages',
#            'value': 262144,
#            'delete': False,
#            'invisible_to_user': False,
#            'value_type': 'array'}],
#          'sub_type': 'HOST_LANGUAGE',
#          'states': []},
#         {'selected': False,
#          'type': 'checkbox',
#          'title': 'Sign',
#          'params': [{'key': 'languages',
#            'value': 524288,
#            'delete': False,
#            'invisible_to_user': False,
#            'value_type': 'array'}],
#          'sub_type': 'HOST_LANGUAGE',
#          'states': []},
#         {'selected': False,
#          'type': 'checkbox',
#          'title': 'עברית',
#          'params': [{'key': 'languages',
#            'value': 1048576,
#            'delete': False,
#            'invisible_to_user': False,
#            'value_type': 'array'}],
#          'sub_type': 'HOST_LANGUAGE',
#          'states': []},
#         {'selected': False,
#          'type': 'checkbox',
#          'title': 'Polski',
#          'params': [{'key': 'languages',
#            'value': 2097152,
#            'delete': False,
#            'invisible_to_user': False,
#            'value_type': 'array'}],
#          'sub_type': 'HOST_LANGUAGE',
#          'states': []},
#         {'selected': False,
#          'type': 'checkbox',
#          'title': 'Bahasa Melayu',
#          'params': [{'key': 'languages',
#            'value': 4194304,
#            'delete': False,
#            'invisible_to_user': False,
#            'value_type': 'array'}],
#          'sub_type': 'HOST_LANGUAGE',
#          'states': []},
#         {'selected': False,
#          'type': 'checkbox',
#          'title': 'Tagalog',
#          'params': [{'key': 'languages',
#            'value': 8388608,
#            'delete': False,
#            'invisible_to_user': False,
#            'value_type': 'array'}],
#          'sub_type': 'HOST_LANGUAGE',
#          'states': []},
#         {'selected': False,
#          'type': 'checkbox',
#          'title': 'Dansk',
#          'params': [{'key': 'languages',
#            'value': 16777216,
#            'delete': False,
#            'invisible_to_user': False,
#            'value_type': 'array'}],
#          'sub_type': 'HOST_LANGUAGE',
#          'states': []},
#         {'selected': False,
#          'type': 'checkbox',
#          'title': 'Svenska',
#          'params': [{'key': 'languages',
#            'value': 33554432,
#            'delete': False,
#            'invisible_to_user': False,
#            'value_type': 'array'}],
#          'sub_type': 'HOST_LANGUAGE',
#          'states': []},
#         {'selected': False,
#          'type': 'checkbox',
#          'title': 'Norsk',
#          'params': [{'key': 'languages',
#            'value': 67108864,
#            'delete': False,
#            'invisible_to_user': False,
#            'value_type': 'array'}],
#          'sub_type': 'HOST_LANGUAGE',
#          'states': []},
#         {'selected': False,
#          'type': 'checkbox',
#          'title': 'Suomi',
#          'params': [{'key': 'languages',
#            'value': 134217728,
#            'delete': False,
#            'invisible_to_user': False,
#            'value_type': 'array'}],
#          'sub_type': 'HOST_LANGUAGE',
#          'states': []},
#         {'selected': False,
#          'type': 'checkbox',
#          'title': 'Čeština',
#          'params': [{'key': 'languages',
#            'value': 268435456,
#            'delete': False,
#            'invisible_to_user': False,
#            'value_type': 'array'}],
#          'sub_type': 'HOST_LANGUAGE',
#          'states': []},
#         {'selected': False,
#          'type': 'checkbox',
#          'title': 'Magyar',
#          'params': [{'key': 'languages',
#            'value': 536870912,
#            'delete': False,
#            'invisible_to_user': False,
#            'value_type': 'array'}],
#          'sub_type': 'HOST_LANGUAGE',
#          'states': []},
#         {'selected': False,
#          'type': 'checkbox',
#          'title': 'Українська',
#          'params': [{'key': 'languages',
#            'value': 1073741824,
#            'delete': False,
#            'invisible_to_user': False,
#            'value_type': 'array'}],
#          'sub_type': 'HOST_LANGUAGE',
#          'states': []}],
#        'selected': False,
#        'title': "Langue de l'hôte",
#        'filter_section_id': 'host_language',
#        'expand_text': "Afficher toutes les langues de l'hôte",
#        'collapse_text': "Fermer la langue de l'hôte",
#        'bar_items': [],
#        'subsections': [],
#        'experiments_metadata': [],
#        'collapse_subtitle': 'English, Français, Deutsch, +28 autres',
#        'collapse_selected_subtitles': []}],
#      'more_filters_button': {'text': 'Afficher plus de 300\xa0séjours',
#       'verified': False,
#       'bg_color': '#008489'},
#      'filter_bar_ordering': {'default': ['date_picker',
#        'guest_picker',
#        'work_trip',
#        'room_type',
#        'price_range',
#        'instant_book'],
#       'small': ['date_picker', 'guest_picker', 'work_trip'],
#       'medium': ['date_picker', 'guest_picker', 'work_trip', 'room_type']},
#      'more_filters_ordering': {'default': ['more_filters_experiment_assignment',
#        'rooms_and_beds',
#        'listing_tier',
#        'host_promotion_type',
#        'other_options',
#        'amenities',
#        'facilities',
#        'property_types',
#        'unique_homes',
#        'house_rules',
#        'family_trip',
#        'neighborhoods',
#        'host_language'],
#       'small': ['more_filters_experiment_assignment',
#        'instant_book',
#        'listing_tier',
#        'price_range',
#        'room_type',
#        'rooms_and_beds',
#        'host_promotion_type',
#        'other_options',
#        'amenities',
#        'facilities',
#        'property_types',
#        'unique_homes',
#        'house_rules',
#        'family_trip',
#        'neighborhoods',
#        'host_language'],
#       'medium': ['more_filters_experiment_assignment',
#        'price_range',
#        'listing_tier',
#        'rooms_and_beds',
#        'instant_book',
#        'host_promotion_type',
#        'other_options',
#        'amenities',
#        'facilities',
#        'property_types',
#        'unique_homes',
#        'house_rules',
#        'family_trip',
#        'neighborhoods',
#        'host_language']},
#      'more_filters_counts': {'default': 0, 'small': 0, 'medium': 0},
#      'filter_bar_counts': {'default': [0, 0, 0, 0, 0, 0],
#       'small': [0, 0, 0],
#       'medium': [0, 0, 0, 0]},
#      'show_left_filters_panel': False,
#      'eligible_for_left_filters_panel': False}}}],
#  'metadata': {'current_tab_id': 'home_tab',
#   'request_uuid': 'fa83c9a7-40e8-eb03-7405-70a56b436b97',
#   'search_id': 'fa83c9a7-40e8-eb03-7405-70a56b436b97',
#   'show_home_collection': 1,
#   'query': 'Paris, France',
#   'query_text': 'Paris · Logements',
#   'current_refinement_paths': ['/homes'],
#   'federated_search_id': 'b9a46fca-07aa-4ac3-b0f1-98fc4d53c9f0',
#   'federated_search_session_id': 'ee30df88-37c6-426b-bd2e-743260bac5d8',
#   'suggestions': [{'title': 'Tout',
#     'type': 'for_you',
#     'search_params': {'params': [],
#      'place_id': 'ChIJD7fiBh9u5kcRYJSMaMOCCwQ',
#      'query': 'Paris, France',
#      'refinement_paths': ['/for_you'],
#      'refinement_path': '/for_you',
#      'tab_id': 'all_tab',
#      'reset_filters': False,
#      'reset_keys': []},
#     'is_selected': False,
#     'fully_qualified_title': 'Paris, France · Tout'},
#    {'title': 'Logements',
#     'type': 'homes',
#     'search_params': {'params': [],
#      'place_id': 'ChIJD7fiBh9u5kcRYJSMaMOCCwQ',
#      'query': 'Paris, France',
#      'refinement_paths': ['/homes'],
#      'refinement_path': '/homes',
#      'tab_id': 'home_tab',
#      'reset_filters': False,
#      'reset_keys': []},
#     'is_selected': True,
#     'fully_qualified_title': 'Paris, France · Logements'},
#    {'title': 'Expériences',
#     'type': 'experiences',
#     'search_params': {'params': [],
#      'place_id': 'ChIJD7fiBh9u5kcRYJSMaMOCCwQ',
#      'query': 'Paris, France',
#      'refinement_paths': ['/experiences'],
#      'refinement_path': '/experiences',
#      'tab_id': 'experience_tab',
#      'reset_filters': False,
#      'reset_keys': []},
#     'is_selected': False,
#     'fully_qualified_title': 'Paris, France · Expériences'},
#    {'title': 'Restaurants',
#     'type': 'restaurants',
#     'search_params': {'params': [],
#      'place_id': 'ChIJD7fiBh9u5kcRYJSMaMOCCwQ',
#      'query': 'Paris, France',
#      'refinement_paths': ['/restaurants'],
#      'refinement_path': '/restaurants',
#      'tab_id': 'restaurant_tab',
#      'reset_filters': False,
#      'reset_keys': []},
#     'is_selected': False,
#     'fully_qualified_title': 'Paris, France · Restaurants'}],
#   'has_map': True,
#   'show_as_hint': False,
#   'marquee_mode': 'DEFAULT',
#   'satori_version': '1.0.3',
#   'gtm_experiments': [],
#   'saved_search_responses': [],
#   'map_toggle': True,
#   'price_display_strategy': 'SHOW_PER_NIGHT_PRICE_AND_TOTAL_PRICE',
#   'satori_config': {'market': 'Paris',
#    'state_code': '',
#    'country_code': 'FR',
#    'region_id': -1,
#    'version': '1.1.9'},
#   'page_metadata': {'page_title': 'Paris · Logements · Airbnb',
#    'render_type': 'EXPLORE',
#    'location_query': False},
#   'geography': {'accuracy': 4,
#    'city': 'Paris',
#    'country_code': 'FR',
#    'country': 'France',
#    'lat': 48.856614,
#    'lng': 2.3522219,
#    'place_id': 'ChIJD7fiBh9u5kcRYJSMaMOCCwQ',
#    'precision': 'city',
#    'result_type': 'locality',
#    'state': 'Île-de-France',
#    'state_short': 'Île-de-France',
#    'extended_precision': 'city',
#    'full_address': 'Paris, France',
#    'market': 'Paris',
#    'province': 'Paris'},
#   'refinement_display_text': 'Logements',
#   'recent_searches_responses': {},
#   'parent_administrative_area': {}}}

# %%
flat_data = json_normalize(result)
flat_data
# Out:
#                                         explore_tabs  \
# 0  [{'tab_id': 'home_tab', 'tab_name': 'homes', '...
#
#   metadata.current_refinement_paths metadata.current_tab_id  \
# 0                          [/homes]                home_tab
#
#            metadata.federated_search_id  metadata.federated_search_session_id  \
# 0  b9a46fca-07aa-4ac3-b0f1-98fc4d53c9f0  ee30df88-37c6-426b-bd2e-743260bac5d8
#
#    metadata.geography.accuracy metadata.geography.city  \
# 0                            4                   Paris
#
#   metadata.geography.country metadata.geography.country_code  \
# 0                     France                              FR
#
#   metadata.geography.extended_precision  ... metadata.satori_config.market  \
# 0                                  city  ...                         Paris
#
#    metadata.satori_config.region_id  metadata.satori_config.state_code  \
# 0                                -1
#
#   metadata.satori_config.version metadata.satori_version  \
# 0                          1.1.9                   1.0.3
#
#   metadata.saved_search_responses                    metadata.search_id  \
# 0                              []  fa83c9a7-40e8-eb03-7405-70a56b436b97
#
#   metadata.show_as_hint metadata.show_home_collection  \
# 0                 False                             1
#
#                                 metadata.suggestions
# 0  [{'title': 'Tout', 'type': 'for_you', 'search_...
#
# [1 rows x 43 columns]

# %%
flat_data1 = json_normalize(flat_data.explore_tabs[0])
flat_data1
# Out:
#   experiments_metadata                      home_tab_metadata.breadcrumbs  \
# 0                   []  [{'location_name': 'France', 'canonical_locati...
#
#    home_tab_metadata.filters.eligible_for_left_filters_panel  \
# 0                                              False
#
#   home_tab_metadata.filters.filter_bar_counts.default  \
# 0                                 [0, 0, 0, 0, 0, 0]
#
#   home_tab_metadata.filters.filter_bar_counts.medium  \
# 0                                       [0, 0, 0, 0]
#
#   home_tab_metadata.filters.filter_bar_counts.small  \
# 0                                         [0, 0, 0]
#
#   home_tab_metadata.filters.filter_bar_ordering.default  \
# 0  [date_picker, guest_picker, work_trip, room_ty...
#
#   home_tab_metadata.filters.filter_bar_ordering.medium  \
# 0  [date_picker, guest_picker, work_trip, room_type]
#
#   home_tab_metadata.filters.filter_bar_ordering.small  \
# 0             [date_picker, guest_picker, work_trip]
#
#   home_tab_metadata.filters.more_filters_button.bg_color  ...  \
# 0                                            #008489      ...
#
#   pagination_metadata.has_next_page  pagination_metadata.has_previous_page  \
# 0                              True                                   True
#
#    pagination_metadata.items_offset  \
# 0                                36
#
#    pagination_metadata.previous_page_items_offset  \
# 0                                               0
#
#    pagination_metadata.previous_page_section_offset  \
# 0                                                 0
#
#   pagination_metadata.search_session_id pagination_metadata.section_offset  \
# 0  ee6574c4-503c-4dde-b625-995705a73e10                                  9
#
#                                             sections    tab_id  tab_name
# 0  [{'backend_search_id': '74ff98b8-6ee7-4885-85a...  home_tab     homes
#
# [1 rows x 65 columns]

# %%
flat_data2 = json_normalize(flat_data1.sections[0])

# %%
flat_data2
# Out:
#                       backend_search_id bankai_section_id breadcrumbs  \
# 0  74ff98b8-6ee7-4885-85af-ab337352f7d8                76          []
#
#   display_type experiments_metadata hotel_tonight_rooms  is_paginated  \
# 0         grid                   []                  []          True
#
#                                             listings localized_listing_count  \
# 0  [{'listing': {'badges': [], 'bathroom_label': ...                  10 000
#
#   nearby_locations  ... section_component_type  \
# 0               []  ...          LISTINGS_GRID
#
#                              section_id section_metadata.card_layout  \
# 0  ee6574c4-503c-4dde-b625-995705a73e10                   HORIZONTAL
#
#   section_metadata.has_show_price_cta section_metadata.is_mimicking_paginated  \
# 0                               False                                   False
#
#   section_metadata.see_all_button_outline_color  \
# 0                                       #008489
#
#   section_metadata.see_all_button_text_color  \
# 0                                    #008489
#
#    section_metadata.see_all_link_text_color  \
# 0                                   #008489
#
#    section_metadata.should_hide_items_from_map section_type_uid
# 0                                        False  PAGINATED_HOMES
#
# [1 rows x 24 columns]

# %%
flat_data3 = json_normalize(flat_data2.listings[0])

# %%
flat_data3
# Out:
#                                   listing.amenity_ids  listing.avg_rating  \
# 0   [1, 129, 3, 4, 8, 77, 21, 89, 90, 91, 92, 93, ...                4.82
# 1   [1, 33, 129, 2, 34, 3, 4, 8, 40, 44, 45, 77, 4...                4.12
# 2   [1, 33, 34, 35, 4, 36, 39, 8, 40, 72, 104, 41,...                4.76
# 3   [1, 33, 35, 4, 36, 8, 40, 41, 44, 45, 77, 47, ...                4.01
# 4   [1, 33, 34, 3, 35, 4, 5, 39, 8, 40, 44, 45, 77...                4.41
# 5   [1, 35, 4, 8, 40, 72, 41, 42, 44, 45, 77, 46, ...                4.70
# 6   [1, 129, 2, 4, 8, 77, 85, 89, 90, 91, 93, 30, ...                4.22
# 7   [96, 1, 33, 34, 131, 4, 8, 45, 46, 15, 85, 23,...                5.00
# 8   [1, 4, 8, 10, 77, 23, 89, 90, 91, 93, 30, 94, ...                4.41
# 9   [1, 2, 3, 4, 8, 72, 77, 21, 85, 89, 90, 91, 92...                4.76
# 10  [64, 1, 129, 2, 66, 3, 4, 6, 71, 8, 72, 9, 11,...                4.74
# 11  [1, 33, 2, 3, 35, 4, 36, 8, 40, 41, 44, 45, 46...                4.78
# 12  [1, 2, 4, 5, 8, 77, 85, 86, 23, 89, 90, 91, 93...                4.90
# 13                      [1, 3, 4, 40, 11, 12, 30, 31]                4.27
# 14  [128, 1, 2, 3, 4, 6, 8, 10, 12, 21, 28, 30, 31...                4.47
# 15             [33, 35, 4, 8, 40, 57, 12, 45, 30, 46]                4.75
# 16  [1, 2, 4, 8, 72, 10, 12, 77, 85, 86, 89, 90, 9...                4.40
# 17  [1, 35, 4, 36, 71, 8, 40, 104, 41, 44, 45, 77,...                4.67
#
#    listing.badges listing.bathroom_label  listing.bathrooms listing.bed_label  \
# 0              []        1 salle de bain                1.0            2 lits
# 1              []        1 salle de bain                1.0            3 lits
# 2              []        1 salle de bain                1.0            2 lits
# 3    [PERLE RARE]        1 salle de bain                1.0            2 lits
# 4    [PERLE RARE]        1 salle de bain                1.0            3 lits
# 5              []      1,5 salle de bain                1.5            2 lits
# 6              []        1 salle de bain                1.0            2 lits
# 7              []      1,5 salle de bain                1.5            2 lits
# 8              []      1,5 salle de bain                1.5            3 lits
# 9              []        1 salle de bain                1.0            4 lits
# 10   [PERLE RARE]        1 salle de bain                1.0             1 lit
# 11             []        1 salle de bain                1.0            3 lits
# 12             []        1 salle de bain                1.0            2 lits
# 13             []        1 salle de bain                1.0            2 lits
# 14   [PERLE RARE]        1 salle de bain                1.0            2 lits
# 15             []        1 salle de bain                1.0            3 lits
# 16   [PERLE RARE]        1 salle de bain                1.0            4 lits
# 17             []        1 salle de bain                1.0            2 lits
#
#    listing.bedroom_label  listing.bedrooms  listing.beds      listing.city  \
# 0             2 chambres                 2             2             Paris
# 1              1 chambre                 1             3             Paris
# 2                 Studio                 0             2             Paris
# 3              1 chambre                 1             2             Paris
# 4              1 chambre                 1             3             Paris
# 5              1 chambre                 1             2             Paris
# 6                 Studio                 0             2             Paris
# 7              1 chambre                 1             2             Paris
# 8             2 chambres                 2             3             Paris
# 9             2 chambres                 2             4             Paris
# 10             1 chambre                 1             1             Paris
# 11            2 chambres                 2             3             Paris
# 12                Studio                 0             2  Nogent-sur-Marne
# 13             1 chambre                 1             2             Paris
# 14            2 chambres                 2             2             Paris
# 15                Studio                 0             3             Paris
# 16             1 chambre                 1             4             Paris
# 17             1 chambre                 1             2       Saint-Mandé
#
#     ... pricing_quote.rate_with_service_fee.amount_formatted  \
# 0   ...                                               110€
# 1   ...                                                79€
# 2   ...                                               119€
# 3   ...                                                83€
# 4   ...                                               108€
# 5   ...                                                89€
# 6   ...                                                86€
# 7   ...                                               106€
# 8   ...                                               129€
# 9   ...                                               164€
# 10  ...                                                94€
# 11  ...                                               158€
# 12  ...                                                70€
# 13  ...                                                70€
# 14  ...                                               107€
# 15  ...                                                77€
# 16  ...                                                99€
# 17  ...                                                84€
#
#    pricing_quote.rate_with_service_fee.currency  \
# 0                                           EUR
# 1                                           EUR
# 2                                           EUR
# 3                                           EUR
# 4                                           EUR
# 5                                           EUR
# 6                                           EUR
# 7                                           EUR
# 8                                           EUR
# 9                                           EUR
# 10                                          EUR
# 11                                          EUR
# 12                                          EUR
# 13                                          EUR
# 14                                          EUR
# 15                                          EUR
# 16                                          EUR
# 17                                          EUR
#
#    pricing_quote.rate_with_service_fee.is_micros_accuracy  \
# 0                                               False
# 1                                               False
# 2                                               False
# 3                                               False
# 4                                               False
# 5                                               False
# 6                                               False
# 7                                               False
# 8                                               False
# 9                                               False
# 10                                              False
# 11                                              False
# 12                                              False
# 13                                              False
# 14                                              False
# 15                                              False
# 16                                              False
# 17                                              False
#
#    pricing_quote.should_show_from_label pricing_quote.weekly_price_factor  \
# 0                                 False                              0.95
# 1                                 False                              1.00
# 2                                 False                              1.00
# 3                                 False                              1.00
# 4                                 False                              0.85
# 5                                 False                              0.85
# 6                                 False                              0.95
# 7                                 False                              1.00
# 8                                 False                              1.00
# 9                                 False                              0.95
# 10                                False                              0.90
# 11                                False                              0.75
# 12                                False                              1.00
# 13                                False                              0.84
# 14                                False                              0.95
# 15                                False                              1.00
# 16                                False                              0.95
# 17                                False                              0.95
#
#     verified.badge_secondary_text  verified.badge_text  verified.enabled  \
# 0                         Vérifié                 Plus             False
# 1                         Vérifié                 Plus             False
# 2                         Vérifié                 Plus             False
# 3                         Vérifié                 Plus             False
# 4                         Vérifié                 Plus             False
# 5                         Vérifié                 Plus             False
# 6                         Vérifié                 Plus             False
# 7                         Vérifié                 Plus             False
# 8                         Vérifié                 Plus             False
# 9                         Vérifié                 Plus             False
# 10                        Vérifié                 Plus             False
# 11                        Vérifié                 Plus             False
# 12                        Vérifié                 Plus             False
# 13                        Vérifié                 Plus             False
# 14                        Vérifié                 Plus             False
# 15                        Vérifié                 Plus             False
# 16                        Vérifié                 Plus             False
# 17                        Vérifié                 Plus             False
#
#     verified.kicker_badge_type verified_card
# 0                       filled         False
# 1                       filled         False
# 2                       filled         False
# 3                       filled         False
# 4                       filled         False
# 5                       filled         False
# 6                       filled         False
# 7                       filled         False
# 8                       filled         False
# 9                       filled         False
# 10                      filled         False
# 11                      filled         False
# 12                      filled         False
# 13                      filled         False
# 14                      filled         False
# 15                      filled         False
# 16                      filled         False
# 17                      filled         False
#
# [18 rows x 102 columns]

# %%
flat_data3.columns
# Out:
# Index(['listing.amenity_ids', 'listing.avg_rating', 'listing.badges',
#        'listing.bathroom_label', 'listing.bathrooms', 'listing.bed_label',
#        'listing.bedroom_label', 'listing.bedrooms', 'listing.beds',
#        'listing.city',
#        ...
#        'pricing_quote.rate_with_service_fee.amount_formatted',
#        'pricing_quote.rate_with_service_fee.currency',
#        'pricing_quote.rate_with_service_fee.is_micros_accuracy',
#        'pricing_quote.should_show_from_label',
#        'pricing_quote.weekly_price_factor', 'verified.badge_secondary_text',
#        'verified.badge_text', 'verified.enabled', 'verified.kicker_badge_type',
#        'verified_card'],
#       dtype='object', length=102)

# %%
flat_data1['pagination_metadata.has_next_page'][0]
# Out:
# True

# %%
a = flat_data1['pagination_metadata.has_next_page'][0]

# %% [markdown]
# # Run through all the pages

# %%
df=pd.DataFrame()
import time

# %%
page_nb = 0
while a == True:
    page_nb +=1
    n =18*page_nb
    url = f'https://www.airbnb.fr/api/v2/explore_tabs?_format=for_explore_search_web&_intents=p1&adults={nb_adults}&auto_ib=false&checkin={customer_checkin_date}&checkout={customer_checkout_date}&children={nb_children}&currency=EUR&current_tab_id=home_tab&experiences_per_grid=20&fetch_filters=true&guidebooks_per_grid=20&has_zero_guest_treatment=true&infants={nb_infants}&is_guided_search=true&is_new_cards_experiment=true&is_standard_search=true&items_offset={n}&items_per_grid=18&key=d306zoyjsyarp7ifhu67rjxn52tv0t20&locale=fr&luxury_pre_launch=true&metadata_only=false&place_id=ChIJD7fiBh9u5kcRYJSMaMOCCwQ&query=Paris%2C%20France&query_understanding_enabled=true&refinement_paths%5B%5D=%2Fhomes&s_tag=35-eYpuX&satori_version=1.1.9&screen_height=719&screen_size=medium&screen_width=750&search_type=pagination&section_offset=9&selected_tab_id=home_tab&show_groupings=true&supports_for_you_v3=true&timezone_offset=120&version=1.5.8'
    response= requests.get(url)
    result = response.json()
    flattened_data = json_normalize(result)
    flattened_data = json_normalize(flattened_data.explore_tabs[0])
    a = flattened_data ['pagination_metadata.has_next_page'][0]
    flattened_data = json_normalize(flattened_data.sections[0])
    flattened_data = json_normalize(flattened_data.listings[0])
    flattened_data = flattened_data.set_index('listing.id')
    df = df.append(flattened_data) 
    time.sleep(1)
df
# Out:
#                                           listing.amenity_ids  \
# listing.id
# 12431613    [1, 129, 3, 4, 8, 77, 21, 89, 90, 91, 92, 93, ...
# 6697074     [1, 33, 129, 2, 34, 3, 4, 8, 40, 44, 45, 77, 4...
# 20682202    [1, 33, 34, 35, 4, 36, 39, 8, 40, 72, 104, 41,...
# 26612229    [1, 33, 35, 4, 36, 8, 40, 41, 44, 45, 77, 47, ...
# 5654383     [1, 33, 34, 3, 35, 4, 5, 39, 8, 40, 44, 45, 77...
# 33082947    [1, 35, 4, 8, 40, 72, 41, 42, 44, 45, 77, 46, ...
# 20742140    [1, 129, 2, 4, 8, 77, 85, 89, 90, 91, 93, 30, ...
# 32326753    [96, 1, 33, 34, 131, 4, 8, 45, 46, 15, 85, 23,...
# 23571603    [1, 4, 8, 10, 77, 23, 89, 90, 91, 93, 30, 94, ...
# 15542883    [1, 2, 3, 4, 8, 72, 77, 21, 85, 89, 90, 91, 92...
# 1070274     [64, 1, 129, 2, 66, 3, 4, 6, 71, 8, 72, 9, 11,...
# 416129      [1, 33, 2, 3, 35, 4, 36, 8, 40, 41, 44, 45, 46...
# 14994130    [1, 2, 4, 5, 8, 77, 85, 86, 23, 89, 90, 91, 93...
# 1475524                         [1, 3, 4, 40, 11, 12, 30, 31]
# 1076722     [128, 1, 2, 3, 4, 6, 8, 10, 12, 21, 28, 30, 31...
# 31253885               [33, 35, 4, 8, 40, 57, 12, 45, 30, 46]
# 9825542     [1, 2, 4, 8, 72, 10, 12, 77, 85, 86, 89, 90, 9...
# 31728633    [1, 35, 4, 36, 71, 8, 40, 104, 41, 44, 45, 77,...
# 29919515    [1, 33, 2, 4, 8, 40, 41, 44, 46, 16, 89, 90, 9...
# 37481238    [1, 33, 131, 4, 8, 40, 42, 11, 12, 44, 46, 21,...
# 13592356    [1, 2, 4, 8, 73, 77, 85, 86, 88, 89, 90, 91, 9...
# 31728633    [1, 35, 4, 36, 71, 8, 40, 104, 41, 44, 45, 77,...
# 37763841    [1, 129, 2, 4, 8, 10, 77, 21, 89, 90, 91, 93, ...
# 7397        [1, 33, 129, 2, 3, 35, 4, 36, 8, 40, 41, 10, 4...
# 20233344    [64, 65, 66, 4, 68, 8, 9, 10, 74, 77, 85, 90, ...
# 33717543    [1, 33, 129, 66, 35, 4, 103, 8, 40, 104, 9, 41...
# 3777799     [1, 129, 2, 66, 3, 4, 68, 8, 77, 85, 86, 89, 9...
# 31708383              [16, 1, 35, 40, 41, 57, 44, 45, 30, 46]
# 31253885               [33, 35, 4, 8, 40, 57, 12, 45, 30, 46]
# 6792978     [1, 4, 8, 10, 12, 77, 21, 89, 90, 91, 93, 30, ...
# ...                                                       ...
# 37246141    [32, 1, 33, 129, 34, 35, 4, 36, 37, 39, 8, 41,...
# 34298068    [1, 129, 4, 132, 5, 72, 77, 85, 86, 89, 90, 91...
# 13780542    [1, 129, 3, 4, 8, 10, 77, 21, 89, 90, 91, 93, ...
# 29043237    [1, 129, 66, 4, 8, 73, 10, 77, 85, 86, 88, 89,...
# 34197580    [1, 33, 34, 4, 8, 40, 104, 44, 46, 47, 89, 90,...
# 30468415    [1, 4, 5, 8, 77, 85, 86, 89, 90, 91, 92, 93, 3...
# 16000388    [33, 35, 4, 8, 40, 104, 10, 11, 107, 44, 46, 4...
# 505610        [1, 33, 3, 35, 4, 6, 8, 40, 21, 89, 91, 92, 30]
# 29239705    [96, 1, 33, 35, 4, 8, 40, 10, 42, 44, 45, 46, ...
# 22596412    [131, 4, 8, 11, 77, 21, 85, 86, 87, 88, 90, 91...
# 9617895     [1, 2, 4, 8, 77, 85, 86, 87, 88, 89, 90, 91, 9...
# 2391541     [1, 2, 66, 4, 71, 8, 10, 77, 21, 89, 91, 92, 9...
# 9617895     [1, 2, 4, 8, 77, 85, 86, 87, 88, 89, 90, 91, 9...
# 2391541     [1, 2, 66, 4, 71, 8, 10, 77, 21, 89, 91, 92, 9...
# 2024381     [1, 2, 3, 131, 4, 5, 8, 73, 77, 17, 20, 85, 86...
# 27242148    [96, 1, 33, 3, 35, 4, 8, 40, 41, 44, 45, 77, 4...
# 36341901    [1, 33, 34, 35, 4, 37, 8, 40, 11, 44, 46, 21, ...
# 21445919         [33, 129, 35, 4, 8, 40, 104, 10, 45, 77, 30]
# 532742      [1, 33, 2, 34, 3, 35, 131, 4, 36, 8, 40, 104, ...
# 36331096    [1, 4, 8, 10, 89, 90, 91, 93, 30, 94, 95, 96, ...
# 1342096     [64, 1, 129, 3, 35, 4, 36, 39, 103, 8, 40, 72,...
# 6291270                 [33, 50, 3, 4, 39, 8, 40, 11, 30, 31]
# 9804370     [1, 33, 34, 3, 4, 8, 40, 41, 44, 45, 46, 47, 3...
# 19306       [1, 33, 2, 3, 35, 4, 36, 5, 103, 8, 40, 72, 10...
# 25603772    [1, 33, 35, 4, 8, 40, 41, 44, 45, 46, 47, 30, 31]
# 12817885    [33, 129, 34, 4, 8, 40, 41, 45, 77, 46, 47, 90...
# 3593610     [1, 2, 3, 131, 4, 8, 12, 77, 21, 85, 86, 89, 9...
# 11645238    [1, 2, 3, 4, 6, 8, 77, 21, 85, 90, 91, 92, 93,...
# 26055995    [1, 33, 35, 4, 36, 103, 8, 40, 104, 41, 44, 45...
# 328697      [1, 33, 2, 3, 4, 8, 41, 11, 12, 44, 45, 46, 21...
#
#             listing.avg_rating listing.badges    listing.bathroom_label  \
# listing.id
# 12431613                  4.82             []           1 salle de bain
# 6697074                   4.12             []           1 salle de bain
# 20682202                  4.76             []           1 salle de bain
# 26612229                  4.01   [PERLE RARE]           1 salle de bain
# 5654383                   4.41   [PERLE RARE]           1 salle de bain
# 33082947                  4.70             []         1,5 salle de bain
# 20742140                  4.22             []           1 salle de bain
# 32326753                  5.00             []         1,5 salle de bain
# 23571603                  4.41             []         1,5 salle de bain
# 15542883                  4.76             []           1 salle de bain
# 1070274                   4.74   [PERLE RARE]           1 salle de bain
# 416129                    4.78             []           1 salle de bain
# 14994130                  4.90             []           1 salle de bain
# 1475524                   4.27             []           1 salle de bain
# 1076722                   4.47   [PERLE RARE]           1 salle de bain
# 31253885                  4.75             []           1 salle de bain
# 9825542                   4.40   [PERLE RARE]           1 salle de bain
# 31728633                  4.67             []           1 salle de bain
# 29919515                  3.79   [PERLE RARE]           1 salle de bain
# 37481238                  4.50   [PERLE RARE]           1 salle de bain
# 13592356                  4.59             []           1 salle de bain
# 31728633                  4.67             []           1 salle de bain
# 37763841                  5.00             []           1 salle de bain
# 7397                      4.69   [PERLE RARE]           1 salle de bain
# 20233344                  4.80             []  1 salle de bain partagée
# 33717543                  4.36             []           1 salle de bain
# 3777799                   4.45             []           1 salle de bain
# 31708383                  4.78             []           1 salle de bain
# 31253885                  4.75             []           1 salle de bain
# 6792978                   4.73   [PERLE RARE]           1 salle de bain
# ...                        ...            ...                       ...
# 37246141                  4.25             []         1,5 salle de bain
# 34298068                  4.87   [PERLE RARE]    1 salle de bain privée
# 13780542                  4.68             []           1 salle de bain
# 29043237                  4.83   [PERLE RARE]           1 salle de bain
# 34197580                  4.71             []           1 salle de bain
# 30468415                  5.00   [PERLE RARE]           1 salle de bain
# 16000388                  4.46             []           1 salle de bain
# 505610                    4.79   [PERLE RARE]           1 salle de bain
# 29239705                  4.87             []           1 salle de bain
# 22596412                  4.56             []           1 salle de bain
# 9617895                   5.00             []           1 salle de bain
# 2391541                   4.27             []           1 salle de bain
# 9617895                   5.00             []           1 salle de bain
# 2391541                   4.27             []           1 salle de bain
# 2024381                   4.88   [PERLE RARE]           1 salle de bain
# 27242148                  4.42             []           1 salle de bain
# 36341901                  0.00             []           1 salle de bain
# 21445919                  4.95             []           1 salle de bain
# 532742                    4.68   [PERLE RARE]           1 salle de bain
# 36331096                  0.00             []           1 salle de bain
# 1342096                   3.92             []           1 salle de bain
# 6291270                   4.00   [PERLE RARE]           1 salle de bain
# 9804370                   4.33             []           1 salle de bain
# 19306                     4.80             []           1 salle de bain
# 25603772                  4.02   [PERLE RARE]           1 salle de bain
# 12817885                  4.75   [PERLE RARE]           1 salle de bain
# 3593610                   4.56             []           1 salle de bain
# 11645238                  4.86             []           1 salle de bain
# 26055995                  4.44             []           1 salle de bain
# 328697                    4.50             []           1 salle de bain
#
#             listing.bathrooms listing.bed_label listing.bedroom_label  \
# listing.id
# 12431613                  1.0            2 lits            2 chambres
# 6697074                   1.0            3 lits             1 chambre
# 20682202                  1.0            2 lits                Studio
# 26612229                  1.0            2 lits             1 chambre
# 5654383                   1.0            3 lits             1 chambre
# 33082947                  1.5            2 lits             1 chambre
# 20742140                  1.0            2 lits                Studio
# 32326753                  1.5            2 lits             1 chambre
# 23571603                  1.5            3 lits            2 chambres
# 15542883                  1.0            4 lits            2 chambres
# 1070274                   1.0             1 lit             1 chambre
# 416129                    1.0            3 lits            2 chambres
# 14994130                  1.0            2 lits                Studio
# 1475524                   1.0            2 lits             1 chambre
# 1076722                   1.0            2 lits            2 chambres
# 31253885                  1.0            3 lits                Studio
# 9825542                   1.0            4 lits             1 chambre
# 31728633                  1.0            2 lits             1 chambre
# 29919515                  1.0             1 lit             1 chambre
# 37481238                  1.0            2 lits             1 chambre
# 13592356                  1.0             1 lit             1 chambre
# 31728633                  1.0            2 lits             1 chambre
# 37763841                  1.0             1 lit             1 chambre
# 7397                      1.0            2 lits            2 chambres
# 20233344                  1.0            3 lits            2 chambres
# 33717543                  1.0            2 lits             1 chambre
# 3777799                   1.0             1 lit             1 chambre
# 31708383                  1.0            2 lits             1 chambre
# 31253885                  1.0            3 lits                Studio
# 6792978                   1.0            2 lits                Studio
# ...                       ...               ...                   ...
# 37246141                  1.5            2 lits            2 chambres
# 34298068                  1.0            3 lits             1 chambre
# 13780542                  1.0            2 lits             1 chambre
# 29043237                  1.0            2 lits             1 chambre
# 34197580                  1.0            2 lits             1 chambre
# 30468415                  1.0            2 lits             1 chambre
# 16000388                  1.0            2 lits             1 chambre
# 505610                    1.0            2 lits             1 chambre
# 29239705                  1.0            2 lits             1 chambre
# 22596412                  1.0            2 lits             1 chambre
# 9617895                   1.0            2 lits             1 chambre
# 2391541                   1.0            3 lits            2 chambres
# 9617895                   1.0            2 lits             1 chambre
# 2391541                   1.0            3 lits            2 chambres
# 2024381                   1.0            3 lits            3 chambres
# 27242148                  1.0            2 lits             1 chambre
# 36341901                  1.0            2 lits             1 chambre
# 21445919                  1.0             1 lit             1 chambre
# 532742                    1.0             1 lit             1 chambre
# 36331096                  1.0            2 lits                Studio
# 1342096                   1.0            2 lits                Studio
# 6291270                   1.0            2 lits             1 chambre
# 9804370                   1.0            2 lits             1 chambre
# 19306                     1.0            2 lits             1 chambre
# 25603772                  1.0            2 lits             1 chambre
# 12817885                  1.0             1 lit             1 chambre
# 3593610                   1.0            2 lits             1 chambre
# 11645238                  1.0            2 lits             1 chambre
# 26055995                  1.0             1 lit             1 chambre
# 328697                    1.0             0 lit             1 chambre
#
#             listing.bedrooms  listing.beds       listing.city  ...  \
# listing.id                                                     ...
# 12431613                   2             2              Paris  ...
# 6697074                    1             3              Paris  ...
# 20682202                   0             2              Paris  ...
# 26612229                   1             2              Paris  ...
# 5654383                    1             3              Paris  ...
# 33082947                   1             2              Paris  ...
# 20742140                   0             2              Paris  ...
# 32326753                   1             2              Paris  ...
# 23571603                   2             3              Paris  ...
# 15542883                   2             4              Paris  ...
# 1070274                    1             1              Paris  ...
# 416129                     2             3              Paris  ...
# 14994130                   0             2   Nogent-sur-Marne  ...
# 1475524                    1             2              Paris  ...
# 1076722                    2             2              Paris  ...
# 31253885                   0             3              Paris  ...
# 9825542                    1             4              Paris  ...
# 31728633                   1             2        Saint-Mandé  ...
# 29919515                   1             1           Bagnolet  ...
# 37481238                   1             2             Vanves  ...
# 13592356                   1             1           Gentilly  ...
# 31728633                   1             2        Saint-Mandé  ...
# 37763841                   1             1              Paris  ...
# 7397                       2             2              Paris  ...
# 20233344                   2             3    Rosny-sous-Bois  ...
# 33717543                   1             2             Antony  ...
# 3777799                    1             1              Paris  ...
# 31708383                   1             2          Vincennes  ...
# 31253885                   0             3              Paris  ...
# 6792978                    0             2              Paris  ...
# ...                      ...           ...                ...  ...
# 37246141                   2             2              Paris  ...
# 34298068                   1             3              Paris  ...
# 13780542                   1             2              Paris  ...
# 29043237                   1             2              Paris  ...
# 34197580                   1             2              Paris  ...
# 30468415                   1             2              Paris  ...
# 16000388                   1             2              Paris  ...
# 505610                     1             2              Paris  ...
# 29239705                   1             2             Vanves  ...
# 22596412                   1             2              Paris  ...
# 9617895                    1             2              Paris  ...
# 2391541                    2             3              Paris  ...
# 9617895                    1             2              Paris  ...
# 2391541                    2             3              Paris  ...
# 2024381                    3             3              Paris  ...
# 27242148                   1             2              Paris  ...
# 36341901                   1             2              Paris  ...
# 21445919                   1             1              Paris  ...
# 532742                     1             1  Neuilly-sur-Seine  ...
# 36331096                   0             2              Paris  ...
# 1342096                    0             2              Paris  ...
# 6291270                    1             2              Paris  ...
# 9804370                    1             2              Paris  ...
# 19306                      1             2              Paris  ...
# 25603772                   1             2              Paris  ...
# 12817885                   1             1          Montreuil  ...
# 3593610                    1             2              Paris  ...
# 11645238                   1             2              Paris  ...
# 26055995                   1             1              Paris  ...
# 328697                     1             0              Paris  ...
#
#            pricing_quote.rate_with_service_fee.amount_formatted  \
# listing.id
# 12431613                                                 110€
# 6697074                                                   79€
# 20682202                                                 119€
# 26612229                                                  83€
# 5654383                                                  108€
# 33082947                                                  89€
# 20742140                                                  86€
# 32326753                                                 106€
# 23571603                                                 129€
# 15542883                                                 164€
# 1070274                                                   94€
# 416129                                                   158€
# 14994130                                                  70€
# 1475524                                                   70€
# 1076722                                                  107€
# 31253885                                                  77€
# 9825542                                                   99€
# 31728633                                                  84€
# 29919515                                                  49€
# 37481238                                                  67€
# 13592356                                                  75€
# 31728633                                                  84€
# 37763841                                                 111€
# 7397                                                     158€
# 20233344                                                  53€
# 33717543                                                  38€
# 3777799                                                   71€
# 31708383                                                  64€
# 31253885                                                  77€
# 6792978                                                   77€
# ...                                                       ...
# 37246141                                                 109€
# 34298068                                                  97€
# 13780542                                                 128€
# 29043237                                                 110€
# 34197580                                                  96€
# 30468415                                                 122€
# 16000388                                                  91€
# 505610                                                   105€
# 29239705                                                  91€
# 22596412                                                 122€
# 9617895                                                  151€
# 2391541                                                  110€
# 9617895                                                  151€
# 2391541                                                  110€
# 2024381                                                  153€
# 27242148                                                 114€
# 36341901                                                 112€
# 21445919                                                  89€
# 532742                                                   141€
# 36331096                                                 122€
# 1342096                                                   90€
# 6291270                                                   67€
# 9804370                                                   92€
# 19306                                                    151€
# 25603772                                                 101€
# 12817885                                                  65€
# 3593610                                                  151€
# 11645238                                                 129€
# 26055995                                                 101€
# 328697                                                   137€
#
#            pricing_quote.rate_with_service_fee.currency  \
# listing.id
# 12431613                                            EUR
# 6697074                                             EUR
# 20682202                                            EUR
# 26612229                                            EUR
# 5654383                                             EUR
# 33082947                                            EUR
# 20742140                                            EUR
# 32326753                                            EUR
# 23571603                                            EUR
# 15542883                                            EUR
# 1070274                                             EUR
# 416129                                              EUR
# 14994130                                            EUR
# 1475524                                             EUR
# 1076722                                             EUR
# 31253885                                            EUR
# 9825542                                             EUR
# 31728633                                            EUR
# 29919515                                            EUR
# 37481238                                            EUR
# 13592356                                            EUR
# 31728633                                            EUR
# 37763841                                            EUR
# 7397                                                EUR
# 20233344                                            EUR
# 33717543                                            EUR
# 3777799                                             EUR
# 31708383                                            EUR
# 31253885                                            EUR
# 6792978                                             EUR
# ...                                                 ...
# 37246141                                            EUR
# 34298068                                            EUR
# 13780542                                            EUR
# 29043237                                            EUR
# 34197580                                            EUR
# 30468415                                            EUR
# 16000388                                            EUR
# 505610                                              EUR
# 29239705                                            EUR
# 22596412                                            EUR
# 9617895                                             EUR
# 2391541                                             EUR
# 9617895                                             EUR
# 2391541                                             EUR
# 2024381                                             EUR
# 27242148                                            EUR
# 36341901                                            EUR
# 21445919                                            EUR
# 532742                                              EUR
# 36331096                                            EUR
# 1342096                                             EUR
# 6291270                                             EUR
# 9804370                                             EUR
# 19306                                               EUR
# 25603772                                            EUR
# 12817885                                            EUR
# 3593610                                             EUR
# 11645238                                            EUR
# 26055995                                            EUR
# 328697                                              EUR
#
#            pricing_quote.rate_with_service_fee.is_micros_accuracy  \
# listing.id
# 12431613                                                False
# 6697074                                                 False
# 20682202                                                False
# 26612229                                                False
# 5654383                                                 False
# 33082947                                                False
# 20742140                                                False
# 32326753                                                False
# 23571603                                                False
# 15542883                                                False
# 1070274                                                 False
# 416129                                                  False
# 14994130                                                False
# 1475524                                                 False
# 1076722                                                 False
# 31253885                                                False
# 9825542                                                 False
# 31728633                                                False
# 29919515                                                False
# 37481238                                                False
# 13592356                                                False
# 31728633                                                False
# 37763841                                                False
# 7397                                                    False
# 20233344                                                False
# 33717543                                                False
# 3777799                                                 False
# 31708383                                                False
# 31253885                                                False
# 6792978                                                 False
# ...                                                       ...
# 37246141                                                False
# 34298068                                                False
# 13780542                                                False
# 29043237                                                False
# 34197580                                                False
# 30468415                                                False
# 16000388                                                False
# 505610                                                  False
# 29239705                                                False
# 22596412                                                False
# 9617895                                                 False
# 2391541                                                 False
# 9617895                                                 False
# 2391541                                                 False
# 2024381                                                 False
# 27242148                                                False
# 36341901                                                False
# 21445919                                                False
# 532742                                                  False
# 36331096                                                False
# 1342096                                                 False
# 6291270                                                 False
# 9804370                                                 False
# 19306                                                   False
# 25603772                                                False
# 12817885                                                False
# 3593610                                                 False
# 11645238                                                False
# 26055995                                                False
# 328697                                                  False
#
#            pricing_quote.should_show_from_label  \
# listing.id
# 12431613                                  False
# 6697074                                   False
# 20682202                                  False
# 26612229                                  False
# 5654383                                   False
# 33082947                                  False
# 20742140                                  False
# 32326753                                  False
# 23571603                                  False
# 15542883                                  False
# 1070274                                   False
# 416129                                    False
# 14994130                                  False
# 1475524                                   False
# 1076722                                   False
# 31253885                                  False
# 9825542                                   False
# 31728633                                  False
# 29919515                                  False
# 37481238                                  False
# 13592356                                  False
# 31728633                                  False
# 37763841                                  False
# 7397                                      False
# 20233344                                  False
# 33717543                                  False
# 3777799                                   False
# 31708383                                  False
# 31253885                                  False
# 6792978                                   False
# ...                                         ...
# 37246141                                  False
# 34298068                                  False
# 13780542                                  False
# 29043237                                  False
# 34197580                                  False
# 30468415                                  False
# 16000388                                  False
# 505610                                    False
# 29239705                                  False
# 22596412                                  False
# 9617895                                   False
# 2391541                                   False
# 9617895                                   False
# 2391541                                   False
# 2024381                                   False
# 27242148                                  False
# 36341901                                  False
# 21445919                                  False
# 532742                                    False
# 36331096                                  False
# 1342096                                   False
# 6291270                                   False
# 9804370                                   False
# 19306                                     False
# 25603772                                  False
# 12817885                                  False
# 3593610                                   False
# 11645238                                  False
# 26055995                                  False
# 328697                                    False
#
#            pricing_quote.weekly_price_factor  verified.badge_secondary_text  \
# listing.id
# 12431613                                0.95                        Vérifié
# 6697074                                 1.00                        Vérifié
# 20682202                                1.00                        Vérifié
# 26612229                                1.00                        Vérifié
# 5654383                                 0.85                        Vérifié
# 33082947                                0.85                        Vérifié
# 20742140                                0.95                        Vérifié
# 32326753                                1.00                        Vérifié
# 23571603                                1.00                        Vérifié
# 15542883                                0.95                        Vérifié
# 1070274                                 0.90                        Vérifié
# 416129                                  0.75                        Vérifié
# 14994130                                1.00                        Vérifié
# 1475524                                 0.84                        Vérifié
# 1076722                                 0.95                        Vérifié
# 31253885                                1.00                        Vérifié
# 9825542                                 0.95                        Vérifié
# 31728633                                0.95                        Vérifié
# 29919515                                1.00                        Vérifié
# 37481238                                0.80                        Vérifié
# 13592356                                0.87                        Vérifié
# 31728633                                0.95                        Vérifié
# 37763841                                0.90                        Vérifié
# 7397                                    1.00                        Vérifié
# 20233344                                0.90                        Vérifié
# 33717543                                0.81                        Vérifié
# 3777799                                 0.95                        Vérifié
# 31708383                                0.84                        Vérifié
# 31253885                                1.00                        Vérifié
# 6792978                                 0.95                        Vérifié
# ...                                      ...                            ...
# 37246141                                0.90                        Vérifié
# 34298068                                0.80                        Vérifié
# 13780542                                0.90                        Vérifié
# 29043237                                0.88                        Vérifié
# 34197580                                0.95                        Vérifié
# 30468415                                1.00                        Vérifié
# 16000388                                0.79                        Vérifié
# 505610                                  0.85                        Vérifié
# 29239705                                1.00                        Vérifié
# 22596412                                1.00                        Vérifié
# 9617895                                 0.85                        Vérifié
# 2391541                                 0.92                        Vérifié
# 9617895                                 0.85                        Vérifié
# 2391541                                 0.92                        Vérifié
# 2024381                                 0.85                        Vérifié
# 27242148                                0.95                        Vérifié
# 36341901                                0.90                        Vérifié
# 21445919                                0.90                        Vérifié
# 532742                                  0.97                        Vérifié
# 36331096                                1.00                        Vérifié
# 1342096                                 0.81                        Vérifié
# 6291270                                 0.90                        Vérifié
# 9804370                                 0.90                        Vérifié
# 19306                                   1.00                        Vérifié
# 25603772                                1.00                        Vérifié
# 12817885                                0.95                        Vérifié
# 3593610                                 0.95                        Vérifié
# 11645238                                0.89                        Vérifié
# 26055995                                1.00                        Vérifié
# 328697                                  0.92                        Vérifié
#
#             verified.badge_text  verified.enabled verified.kicker_badge_type  \
# listing.id
# 12431613                   Plus             False                     filled
# 6697074                    Plus             False                     filled
# 20682202                   Plus             False                     filled
# 26612229                   Plus             False                     filled
# 5654383                    Plus             False                     filled
# 33082947                   Plus             False                     filled
# 20742140                   Plus             False                     filled
# 32326753                   Plus             False                     filled
# 23571603                   Plus             False                     filled
# 15542883                   Plus             False                     filled
# 1070274                    Plus             False                     filled
# 416129                     Plus             False                     filled
# 14994130                   Plus             False                     filled
# 1475524                    Plus             False                     filled
# 1076722                    Plus             False                     filled
# 31253885                   Plus             False                     filled
# 9825542                    Plus             False                     filled
# 31728633                   Plus             False                     filled
# 29919515                   Plus             False                     filled
# 37481238                   Plus             False                     filled
# 13592356                   Plus             False                     filled
# 31728633                   Plus             False                     filled
# 37763841                   Plus             False                     filled
# 7397                       Plus             False                     filled
# 20233344                   Plus             False                     filled
# 33717543                   Plus             False                     filled
# 3777799                    Plus             False                     filled
# 31708383                   Plus             False                     filled
# 31253885                   Plus             False                     filled
# 6792978                    Plus             False                     filled
# ...                         ...               ...                        ...
# 37246141                   Plus             False                     filled
# 34298068                   Plus             False                     filled
# 13780542                   Plus             False                     filled
# 29043237                   Plus             False                     filled
# 34197580                   Plus             False                     filled
# 30468415                   Plus             False                     filled
# 16000388                   Plus             False                     filled
# 505610                     Plus             False                     filled
# 29239705                   Plus             False                     filled
# 22596412                   Plus             False                     filled
# 9617895                    Plus             False                     filled
# 2391541                    Plus             False                     filled
# 9617895                    Plus             False                     filled
# 2391541                    Plus             False                     filled
# 2024381                    Plus             False                     filled
# 27242148                   Plus             False                     filled
# 36341901                   Plus             False                     filled
# 21445919                   Plus             False                     filled
# 532742                     Plus             False                     filled
# 36331096                   Plus             False                     filled
# 1342096                    Plus             False                     filled
# 6291270                    Plus             False                     filled
# 9804370                    Plus             False                     filled
# 19306                      Plus             False                     filled
# 25603772                   Plus             False                     filled
# 12817885                   Plus             False                     filled
# 3593610                    Plus             False                     filled
# 11645238                   Plus             False                     filled
# 26055995                   Plus             False                     filled
# 328697                     Plus             False                     filled
#
#            verified_card
# listing.id
# 12431613           False
# 6697074            False
# 20682202           False
# 26612229           False
# 5654383            False
# 33082947           False
# 20742140           False
# 32326753           False
# 23571603           False
# 15542883           False
# 1070274            False
# 416129             False
# 14994130           False
# 1475524            False
# 1076722            False
# 31253885           False
# 9825542            False
# 31728633           False
# 29919515           False
# 37481238           False
# 13592356           False
# 31728633           False
# 37763841           False
# 7397               False
# 20233344           False
# 33717543           False
# 3777799            False
# 31708383           False
# 31253885           False
# 6792978            False
# ...                  ...
# 37246141           False
# 34298068           False
# 13780542           False
# 29043237           False
# 34197580           False
# 30468415           False
# 16000388           False
# 505610             False
# 29239705           False
# 22596412           False
# 9617895            False
# 2391541            False
# 9617895            False
# 2391541            False
# 2024381            False
# 27242148           False
# 36341901           False
# 21445919           False
# 532742             False
# 36331096           False
# 1342096            False
# 6291270            False
# 9804370            False
# 19306              False
# 25603772           False
# 12817885           False
# 3593610            False
# 11645238           False
# 26055995           False
# 328697             False
#
# [288 rows x 101 columns]

# %%
response
# Out:
# <Response [200]>

# %%
df.columns.value_counts()
# Out:
# listing.preview_tags                                                 1
# listing.user.thumbnail_url                                           1
# pricing_quote.rate.is_micros_accuracy                                1
# listing.show_structured_name                                         1
# listing.reviews_count                                                1
# listing.neighborhood                                                 1
# listing.star_rating                                                  1
# pricing_quote.rate.amount_formatted                                  1
# listing.kicker_content.messages                                      1
# listing.main_section_message.type                                    1
# listing.wide_kicker_content.text_color                               1
# listing.is_business_travel_ready                                     1
# pricing_quote.rate_with_service_fee.is_micros_accuracy               1
# pricing_quote.should_show_from_label                                 1
# listing.picture.large_ro                                             1
# pricing_quote.rate_type                                              1
# listing.host_thumbnail_url_small                                     1
# pricing_quote.price.total.is_micros_accuracy                         1
# pricing_quote.rate_with_service_fee.amount_formatted                 1
# pricing_quote.price_string                                           1
# pricing_quote.rate_with_service_fee.amount                           1
# verified.kicker_badge_type                                           1
# pricing_quote.can_instant_book                                       1
# listing.space_type                                                   1
# listing.min_nights                                                   1
# listing.user.first_name                                              1
# listing.kicker_content.text_color                                    1
# listing.host_languages                                               1
# pricing_quote.rate.currency                                          1
# pricing_quote.monthly_price_factor                                   1
#                                                                     ..
# listing.bedroom_label                                                1
# listing.is_new_listing                                               1
# listing.beds                                                         1
# pricing_quote.rate_with_service_fee.currency                         1
# listing.room_and_property_type                                       1
# listing.host_thumbnail_url                                           1
# listing.localized_neighborhood                                       1
# listing.user.picture_url                                             1
# listing.picture.id                                                   1
# listing.person_capacity                                              1
# listing.localized_city                                               1
# pricing_quote.price.price_items                                      1
# listing.public_address                                               1
# pricing_quote.price.total.currency                                   1
# pricing_quote.bar_display_price_without_discount.amount_formatted    1
# listing.bed_label                                                    1
# listing.user.id                                                      1
# listing.bedrooms                                                     1
# listing.bathroom_label                                               1
# listing.room_type                                                    1
# listing.reviews                                                      1
# listing.user.smart_name                                              1
# listing.property_type_id                                             1
# listing.formatted_badges                                             1
# listing.picture.scrim_color                                          1
# listing.picture_url                                                  1
# listing.preview_amenities                                            1
# listing.lat                                                          1
# listing.preview_amenity_names                                        1
# listing.license                                                      1
# Length: 101, dtype: int64

# %%
df.to_excel('Airbnb.xlsx')

# %%
drop_cols = ['listing.amenity_ids',
'listing.badges',
'listing.bathroom_label',
'listing.formatted_badges',
'listing.host_thumbnail_url',
'listing.host_thumbnail_url_small',
'listing.is_business_travel_ready',
'listing.is_superhost',
'listing.is_business_travel_ready',
'listing.is_new_listing',
'listing.is_superhost',
'listing.kicker_content.text_color',
'listing.lat',
'listing.license',
'listing.lng',
'listing.map_highlight_status',
'listing.picture.preview_encoded_png',
'listing.picture.saturated_a11y_dark_color',
'listing.picture.scrim_color',
'listing.preview_encoded_png',
'listing.preview_tags',
'listing.property_type_id',
'listing.scrim_color',
'listing.show_photo_swipe_indicator',
'listing.show_structured_name',
'listing.room_type',
'listing.star_rating_color',
'listing.tier_id',
'listing.user.first_name',
'listing.user.has_profile_pic',
'listing.user.id',
'listing.user.is_superhost',
'listing.user.picture_url',
'listing.user.smart_name',
'listing.user.thumbnail_url',
'listing.wide_kicker_content.text_color',
'pricing_quote.bar_display_price_without_discount.amount',
'pricing_quote.bar_display_price_without_discount.is_micros_accuracy',
'pricing_quote.price.price_items',
'pricing_quote.price.total.amount',
'pricing_quote.price.total.is_micros_accuracy',
'pricing_quote.rate.amount',
'pricing_quote.price_string',
'pricing_quote.rate_type',
'pricing_quote.rate_with_service_fee.amount',
'pricing_quote.rate_with_service_fee.is_micros_accuracy',
'pricing_quote.should_show_from_label',
'verified.badge_text',
'verified.enabled',
'verified.kicker_badge_type',
'verified_card',
'pricing_quote.rate.is_micros_accuracy',
'listing.bathrooms',
'listing.bedrooms',
'listing.beds',
'listing.kicker_content.messages',
'pricing_quote.price.localized_title',
'pricing_quote.price.total.currency',
'pricing_quote.rate.currency',
'pricing_quote.rate_with_service_fee.amount_formatted',
'pricing_quote.weekly_price_factor',
'verified.badge_secondary_text',
'listing.localized_city',
'listing.star_rating',
'pricing_quote.rate_with_service_fee.currency',
'pricing_quote.monthly_price_factor',
'pricing_quote.bar_display_price_without_discount.currency',
'pricing_quote.bar_display_price_without_discount.amount_formatted',
'listing.reviews',
'listing.reviews_count',
'listing.room_type_category',
'listing.space_type',
'listing.wide_kicker_content.messages',
'listing.picture_count',
'listing.public_address',
'listing.picture.id',
'listing.picture.dominant_saturated_color',
'listing.picture.large_ro',
'listing.picture.picture',
'listing.main_section_message.type',
'listing.main_section_message.body',
'listing.max_nights','listing.min_nights']

# %%
df1=df.drop(drop_cols, axis=1)

# %%
df1
# Out:
#             listing.avg_rating listing.bed_label listing.bedroom_label  \
# listing.id
# 12431613                  4.82            2 lits            2 chambres
# 6697074                   4.12            3 lits             1 chambre
# 20682202                  4.76            2 lits                Studio
# 26612229                  4.01            2 lits             1 chambre
# 5654383                   4.41            3 lits             1 chambre
# 33082947                  4.70            2 lits             1 chambre
# 20742140                  4.22            2 lits                Studio
# 32326753                  5.00            2 lits             1 chambre
# 23571603                  4.41            3 lits            2 chambres
# 15542883                  4.76            4 lits            2 chambres
# 1070274                   4.74             1 lit             1 chambre
# 416129                    4.78            3 lits            2 chambres
# 14994130                  4.90            2 lits                Studio
# 1475524                   4.27            2 lits             1 chambre
# 1076722                   4.47            2 lits            2 chambres
# 31253885                  4.75            3 lits                Studio
# 9825542                   4.40            4 lits             1 chambre
# 31728633                  4.67            2 lits             1 chambre
# 29919515                  3.79             1 lit             1 chambre
# 37481238                  4.50            2 lits             1 chambre
# 13592356                  4.59             1 lit             1 chambre
# 31728633                  4.67            2 lits             1 chambre
# 37763841                  5.00             1 lit             1 chambre
# 7397                      4.69            2 lits            2 chambres
# 20233344                  4.80            3 lits            2 chambres
# 33717543                  4.36            2 lits             1 chambre
# 3777799                   4.45             1 lit             1 chambre
# 31708383                  4.78            2 lits             1 chambre
# 31253885                  4.75            3 lits                Studio
# 6792978                   4.73            2 lits                Studio
# ...                        ...               ...                   ...
# 37246141                  4.25            2 lits            2 chambres
# 34298068                  4.87            3 lits             1 chambre
# 13780542                  4.68            2 lits             1 chambre
# 29043237                  4.83            2 lits             1 chambre
# 34197580                  4.71            2 lits             1 chambre
# 30468415                  5.00            2 lits             1 chambre
# 16000388                  4.46            2 lits             1 chambre
# 505610                    4.79            2 lits             1 chambre
# 29239705                  4.87            2 lits             1 chambre
# 22596412                  4.56            2 lits             1 chambre
# 9617895                   5.00            2 lits             1 chambre
# 2391541                   4.27            3 lits            2 chambres
# 9617895                   5.00            2 lits             1 chambre
# 2391541                   4.27            3 lits            2 chambres
# 2024381                   4.88            3 lits            3 chambres
# 27242148                  4.42            2 lits             1 chambre
# 36341901                  0.00            2 lits             1 chambre
# 21445919                  4.95             1 lit             1 chambre
# 532742                    4.68             1 lit             1 chambre
# 36331096                  0.00            2 lits                Studio
# 1342096                   3.92            2 lits                Studio
# 6291270                   4.00            2 lits             1 chambre
# 9804370                   4.33            2 lits             1 chambre
# 19306                     4.80            2 lits             1 chambre
# 25603772                  4.02            2 lits             1 chambre
# 12817885                  4.75             1 lit             1 chambre
# 3593610                   4.56            2 lits             1 chambre
# 11645238                  4.86            2 lits             1 chambre
# 26055995                  4.44             1 lit             1 chambre
# 328697                    4.50             0 lit             1 chambre
#
#                  listing.city listing.guest_label listing.host_languages  \
# listing.id
# 12431613                Paris         4 voyageurs           [en, fr, es]
# 6697074                 Paris         4 voyageurs                   [fr]
# 20682202                Paris         4 voyageurs                     []
# 26612229                Paris         4 voyageurs               [en, fr]
# 5654383                 Paris         3 voyageurs   [ar, nl, en, fr, es]
# 33082947                Paris         4 voyageurs                   [en]
# 20742140                Paris         3 voyageurs           [en, fr, he]
# 32326753                Paris         3 voyageurs                     []
# 23571603                Paris         4 voyageurs                     []
# 15542883                Paris         4 voyageurs               [en, fr]
# 1070274                 Paris         3 voyageurs                   [en]
# 416129                  Paris         5 voyageurs               [en, fr]
# 14994130     Nogent-sur-Marne         4 voyageurs                     []
# 1475524                 Paris         3 voyageurs                     []
# 1076722                 Paris         5 voyageurs       [en, fr, de, ja]
# 31253885                Paris         5 voyageurs           [en, fr, de]
# 9825542                 Paris         6 voyageurs                     []
# 31728633          Saint-Mandé         4 voyageurs               [en, fr]
# 29919515             Bagnolet         4 voyageurs                   [fr]
# 37481238               Vanves         4 voyageurs                     []
# 13592356             Gentilly         4 voyageurs               [en, fr]
# 31728633          Saint-Mandé         4 voyageurs               [en, fr]
# 37763841                Paris         3 voyageurs                     []
# 7397                    Paris         4 voyageurs       [en, fr, de, it]
# 20233344      Rosny-sous-Bois         4 voyageurs                     []
# 33717543               Antony         3 voyageurs           [ar, en, fr]
# 3777799                 Paris         3 voyageurs           [en, fr, ru]
# 31708383            Vincennes         3 voyageurs                     []
# 31253885                Paris         5 voyageurs           [en, fr, de]
# 6792978                 Paris         4 voyageurs                     []
# ...                       ...                 ...                    ...
# 37246141                Paris         4 voyageurs       [nl, en, fr, ru]
# 34298068                Paris         4 voyageurs                     []
# 13780542                Paris         3 voyageurs               [en, fr]
# 29043237                Paris         4 voyageurs                     []
# 34197580                Paris         4 voyageurs               [en, fr]
# 30468415                Paris         4 voyageurs                     []
# 16000388                Paris         3 voyageurs                     []
# 505610                  Paris         3 voyageurs               [en, fr]
# 29239705               Vanves         4 voyageurs               [en, fr]
# 22596412                Paris         4 voyageurs                     []
# 9617895                 Paris         4 voyageurs                     []
# 2391541                 Paris         4 voyageurs                     []
# 9617895                 Paris         4 voyageurs                     []
# 2391541                 Paris         4 voyageurs                     []
# 2024381                 Paris         4 voyageurs       [en, fr, it, es]
# 27242148                Paris         3 voyageurs                     []
# 36341901                Paris         3 voyageurs                     []
# 21445919                Paris         3 voyageurs                     []
# 532742      Neuilly-sur-Seine         4 voyageurs               [en, es]
# 36331096                Paris         4 voyageurs               [en, fr]
# 1342096                 Paris         4 voyageurs                     []
# 6291270                 Paris         4 voyageurs                     []
# 9804370                 Paris         4 voyageurs           [en, fr, it]
# 19306                   Paris         4 voyageurs       [en, fr, pt, es]
# 25603772                Paris         3 voyageurs                   [en]
# 12817885            Montreuil         3 voyageurs                     []
# 3593610                 Paris         3 voyageurs           [en, fr, es]
# 11645238                Paris         4 voyageurs               [en, es]
# 26055995                Paris         3 voyageurs           [en, fr, es]
# 328697                  Paris         5 voyageurs               [en, fr]
#
#             listing.localized_neighborhood  \
# listing.id
# 12431613                       La Villette
# 6697074                 11e arrondissement
# 20682202                 2e arrondissement
# 26612229                            Nation
# 5654383                  4e arrondissement
# 33082947                12e arrondissement
# 20742140                 4e arrondissement
# 32326753                    Quartier Latin
# 23571603                11e arrondissement
# 15542883                Commerce - Dupleix
# 1070274       Buttes-Chaumont - Belleville
# 416129      Saint Germain des Prés - Odéon
# 14994130                               NaN
# 1475524                 10e arrondissement
# 1076722                        La Villette
# 31253885                        Montmartre
# 9825542                          Vaugirard
# 31728633                            Nation
# 29919515                20e arrondissement
# 37481238                               NaN
# 13592356                14e arrondissement
# 31728633                            Nation
# 37763841                16e arrondissement
# 7397                     4e arrondissement
# 20233344                               NaN
# 33717543                               NaN
# 3777799                  9e arrondissement
# 31708383                               NaN
# 31253885                        Montmartre
# 6792978                        La Villette
# ...                                    ...
# 37246141                      Montparnasse
# 34298068                      Gare de Lyon
# 13780542                    Quartier Latin
# 29043237                18e arrondissement
# 34197580                18e arrondissement
# 30468415       Tour Eiffel - Champ de Mars
# 16000388                11e arrondissement
# 505610                  13e arrondissement
# 29239705                15e arrondissement
# 22596412                        Montmartre
# 9617895                 10e arrondissement
# 2391541                        La Villette
# 9617895                 10e arrondissement
# 2391541                        La Villette
# 2024381                             Nation
# 27242148                        Montmartre
# 36341901                17e arrondissement
# 21445919                10e arrondissement
# 532742                  16e arrondissement
# 36331096                11e arrondissement
# 1342096                         Montmartre
# 6291270       Père Lachaise - Ménilmontant
# 9804370                  9e arrondissement
# 19306                       Quartier Latin
# 25603772                 4e arrondissement
# 12817885                20e arrondissement
# 3593610     Saint Germain des Prés - Odéon
# 11645238                        Montmartre
# 26055995                18e arrondissement
# 328697      Saint Germain des Prés - Odéon
#
#            listing.main_section_message.headline  \
# listing.id
# 12431613                                     NaN
# 6697074                                      NaN
# 20682202                                     NaN
# 26612229                              PERLE RARE
# 5654383                               PERLE RARE
# 33082947                                     NaN
# 20742140                                     NaN
# 32326753                                     NaN
# 23571603                                     NaN
# 15542883                                     NaN
# 1070274                               PERLE RARE
# 416129                                       NaN
# 14994130                                     NaN
# 1475524                                      NaN
# 1076722                               PERLE RARE
# 31253885                                     NaN
# 9825542                               PERLE RARE
# 31728633                                     NaN
# 29919515                              PERLE RARE
# 37481238                              PERLE RARE
# 13592356                                     NaN
# 31728633                                     NaN
# 37763841                                     NaN
# 7397                                  PERLE RARE
# 20233344                                     NaN
# 33717543                                     NaN
# 3777799                                      NaN
# 31708383                                     NaN
# 31253885                                     NaN
# 6792978                               PERLE RARE
# ...                                          ...
# 37246141                                     NaN
# 34298068                              PERLE RARE
# 13780542                                     NaN
# 29043237                              PERLE RARE
# 34197580                                     NaN
# 30468415                              PERLE RARE
# 16000388                                     NaN
# 505610                                PERLE RARE
# 29239705                                     NaN
# 22596412                                     NaN
# 9617895                                      NaN
# 2391541                                      NaN
# 9617895                                      NaN
# 2391541                                      NaN
# 2024381                               PERLE RARE
# 27242148                                     NaN
# 36341901                                     NaN
# 21445919                                     NaN
# 532742                                PERLE RARE
# 36331096                                     NaN
# 1342096                                      NaN
# 6291270                               PERLE RARE
# 9804370                                      NaN
# 19306                                        NaN
# 25603772                              PERLE RARE
# 12817885                              PERLE RARE
# 3593610                                      NaN
# 11645238                                     NaN
# 26055995                                     NaN
# 328697                                       NaN
#
#                                                  listing.name  \
# listing.id
# 12431613                  NEW Calme Ensoleillé Vue Montmartre
# 6697074                      PARIS CENTRE REPUBLIQUE 2 Pièces
# 20682202     Appartement De designer Aménagé Pour 4 personnes
# 26612229      Superbe apt spacieux dans un quartier dynamique
# 5654383                     Hidden Treasure in Heart of Paris
# 33082947    Charming & cozy apartment for a delightful sta...
# 20742140                                  Paris Studio Marais
# 32326753                                   True Parisian Chic
# 23571603         Appartement spacieux au coeur de la Bastille
# 15542883     3 pièces lumineux et calme. Quartier Tour Eiffel
# 1070274                   Studio with Panoramic view of Paris
# 416129                    Paris 06: 2R Flat in Latin Quarter.
# 14994130                                 Paris centre à 15 mn
# 1475524                      Appartement 2 pièces Paris 10eme
# 1076722              APART. ENTIER BUTTES-CHAUMONT MONTMARTRE
# 31253885    2/4/5 Sleeps Budget-Place 380sqft - Very Hype ...
# 9825542                    Charme au Coeur de Paris Vaugirard
# 31728633    COSY, DESIGN AND LUXURY APARTMENT, 5 MINUTS PARIS
# 29919515                          studio à 50 mètres de Paris
# 37481238                BEAU 2 PIÈCES A VANVES (5MN DE PARIS)
# 13592356                 ❤️❤️Appartement à 2min de PARIS ❤️❤️
# 31728633    COSY, DESIGN AND LUXURY APARTMENT, 5 MINUTS PARIS
# 37763841    *NOUVEAU* SPACIEUX & LUMINEUX 67m2 PLEIN COEUR...
# 7397                         LA VERRERIE - MARAIS- 2/4 PEOPLE
# 20233344    Deux chambres dans un duplex lumineux et spacieux
# 33717543     Appartement à 9min de la gare RER ,15min d'orly,
# 3777799                                    2 pièces  Paris 10
# 31708383                                              la loge
# 31253885    2/4/5 Sleeps Budget-Place 380sqft - Very Hype ...
# 6792978            Studio (près Gares de l'E. du N. et de L.)
# ...                                                       ...
# 37246141    Apprtement well located  in heart of paris  6 eme
# 34298068                     Vivre sur l’eau au cœur de paris
# 13780542                         AU COEUR DU PARIS HISTORIQUE
# 29043237         Agréable appartement sur la butte Montmartre
# 34197580    A proximité de Montmartre,  2 pièces hors du t...
# 30468415           Modern duplex in heart of historical Paris
# 16000388                Appartement lumineux au cœur de Paris
# 505610                       1-bedroom apt with amazing view!
# 29239705    ☀️ Charmant T2 -  Vanves Portes de Paris - 4pe...
# 22596412                       Du charme à Montmartre wifi ok
# 9617895                Minimalist Architect Apartment Paris X
# 2391541                                  Superb 3 rooms Paris
# 9617895                Minimalist Architect Apartment Paris X
# 2391541                                  Superb 3 rooms Paris
# 2024381                    Type loft entre Bastille et Nation
# 27242148          Charmant studio en plein cœur de Montmartre
# 36341901               3 pièces charme Batignolles Montmartre
# 21445919         Nice and cosy flat nearby Canal Saint Martin
# 532742          Paris - Cosy Duplex à 3 mn des Champs Elysées
# 36331096    Grand appartement - Haut du Marais - Cœur de P...
# 1342096                       Studio avec jardin à Montmartre
# 6291270                       Beau deux-pièces à Ménilmontant
# 9804370                      Design 1br Flat South Montmartre
# 19306                   QUARTIER LATIN ROMANTIQUE MAISONNETTE
# 25603772    Brand new little Duplex and Terrace heart of P...
# 12817885       Bel appartement sur cour à 500 mètres de Paris
# 3593610                        Live in Saint Germain des Prés
# 11645238                          Charming flat in Montmartre
# 26055995            Charmant appartement proche de Montmartre
# 328697                    le Panthéon best of Paris 4/5P WIFI
#
#                       listing.neighborhood  listing.person_capacity  \
# listing.id
# 12431613                       La Villette                        4
# 6697074                  XI Arrondissement                        4
# 20682202                 II Arrondissement                        4
# 26612229                            Nation                        4
# 5654383                  IV Arrondissement                        3
# 33082947                XII Arrondissement                        4
# 20742140                 IV Arrondissement                        3
# 32326753                    Quartier Latin                        3
# 23571603                 XI Arrondissement                        4
# 15542883                Commerce - Dupleix                        4
# 1070274       Buttes-Chaumont - Belleville                        3
# 416129      Saint-Germain-des-Prés - Odéon                        5
# 14994130                               NaN                        4
# 1475524                   X Arrondissement                        3
# 1076722                        La Villette                        5
# 31253885                        Montmartre                        5
# 9825542                          Vaugirard                        6
# 31728633                            Nation                        4
# 29919515                 XX Arrondissement                        4
# 37481238                               NaN                        4
# 13592356                XIV Arrondissement                        4
# 31728633                            Nation                        4
# 37763841                XVI Arrondissement                        3
# 7397                     IV Arrondissement                        4
# 20233344                               NaN                        4
# 33717543                               NaN                        3
# 3777799                  IX Arrondissement                        3
# 31708383                               NaN                        3
# 31253885                        Montmartre                        5
# 6792978                        La Villette                        4
# ...                                    ...                      ...
# 37246141                      Montparnasse                        4
# 34298068                      Gare de Lyon                        4
# 13780542                    Quartier Latin                        3
# 29043237              XVIII Arrondissement                        4
# 34197580              XVIII Arrondissement                        4
# 30468415       Tour Eiffel - Champ de Mars                        4
# 16000388                 XI Arrondissement                        3
# 505610                 XIII Arrondissement                        3
# 29239705                 XV Arrondissement                        4
# 22596412                        Montmartre                        4
# 9617895                   X Arrondissement                        4
# 2391541                        La Villette                        4
# 9617895                   X Arrondissement                        4
# 2391541                        La Villette                        4
# 2024381                             Nation                        4
# 27242148                        Montmartre                        3
# 36341901               XVII Arrondissement                        3
# 21445919                  X Arrondissement                        3
# 532742                  XVI Arrondissement                        4
# 36331096                 XI Arrondissement                        4
# 1342096                         Montmartre                        4
# 6291270       Père Lachaise - Ménilmontant                        4
# 9804370                  IX Arrondissement                        4
# 19306                       Quartier Latin                        4
# 25603772                 IV Arrondissement                        3
# 12817885                 XX Arrondissement                        3
# 3593610     Saint-Germain-des-Prés - Odéon                        3
# 11645238                        Montmartre                        4
# 26055995              XVIII Arrondissement                        3
# 328697      Saint-Germain-des-Prés - Odéon                        5
#
#                                           listing.picture_url  \
# listing.id
# 12431613    https://a0.muscache.com/im/pictures/a607defd-a...
# 6697074     https://a0.muscache.com/im/pictures/ccd1bf78-e...
# 20682202    https://a0.muscache.com/im/pictures/c393711d-3...
# 26612229    https://a0.muscache.com/im/pictures/7017d6d9-0...
# 5654383     https://a0.muscache.com/im/pictures/104585129/...
# 33082947    https://a0.muscache.com/im/pictures/b6e9fa62-d...
# 20742140    https://a0.muscache.com/im/pictures/290c7840-9...
# 32326753    https://a0.muscache.com/im/pictures/3fab80a8-f...
# 23571603    https://a0.muscache.com/im/pictures/e142f73b-2...
# 15542883    https://a0.muscache.com/im/pictures/868557e5-6...
# 1070274     https://a0.muscache.com/im/pictures/16090139/c...
# 416129      https://a0.muscache.com/im/pictures/5000794/3f...
# 14994130    https://a0.muscache.com/im/pictures/bef3e90b-3...
# 1475524     https://a0.muscache.com/im/pictures/36998367/1...
# 1076722     https://a0.muscache.com/im/pictures/39213752/8...
# 31253885    https://a0.muscache.com/im/pictures/8e1c4cac-0...
# 9825542     https://a0.muscache.com/im/pictures/71977d16-4...
# 31728633    https://a0.muscache.com/im/pictures/4ef5c58b-0...
# 29919515    https://a0.muscache.com/im/pictures/c15e1142-3...
# 37481238    https://a0.muscache.com/im/pictures/c4b8499c-4...
# 13592356    https://a0.muscache.com/im/pictures/f7a02df6-5...
# 31728633    https://a0.muscache.com/im/pictures/4ef5c58b-0...
# 37763841    https://a0.muscache.com/im/pictures/8d8b680d-9...
# 7397        https://a0.muscache.com/im/pictures/67928287/3...
# 20233344    https://a0.muscache.com/im/pictures/76ec8cf0-e...
# 33717543    https://a0.muscache.com/im/pictures/79b4ab49-5...
# 3777799     https://a0.muscache.com/im/pictures/47538604/0...
# 31708383    https://a0.muscache.com/im/pictures/b3b3cf42-2...
# 31253885    https://a0.muscache.com/im/pictures/8e1c4cac-0...
# 6792978     https://a0.muscache.com/im/pictures/0a12288d-0...
# ...                                                       ...
# 37246141    https://a0.muscache.com/im/pictures/4170bc68-d...
# 34298068    https://a0.muscache.com/im/pictures/c5766788-e...
# 13780542    https://a0.muscache.com/im/pictures/8c666146-f...
# 29043237    https://a0.muscache.com/im/pictures/4aba0163-2...
# 34197580    https://a0.muscache.com/im/pictures/6a76aedd-d...
# 30468415    https://a0.muscache.com/im/pictures/07b1d84a-c...
# 16000388    https://a0.muscache.com/im/pictures/39e2407d-c...
# 505610      https://a0.muscache.com/im/pictures/12907872/f...
# 29239705    https://a0.muscache.com/im/pictures/916c2bca-8...
# 22596412    https://a0.muscache.com/im/pictures/52a8fb6d-f...
# 9617895     https://a0.muscache.com/im/pictures/b0595cb6-d...
# 2391541     https://a0.muscache.com/im/pictures/32667010/e...
# 9617895     https://a0.muscache.com/im/pictures/b0595cb6-d...
# 2391541     https://a0.muscache.com/im/pictures/32667010/e...
# 2024381     https://a0.muscache.com/im/pictures/27774125/d...
# 27242148    https://a0.muscache.com/im/pictures/e3a60d30-7...
# 36341901    https://a0.muscache.com/im/pictures/ddfc31c7-d...
# 21445919    https://a0.muscache.com/im/pictures/23746f5e-4...
# 532742      https://a0.muscache.com/im/pictures/ef9e906b-e...
# 36331096    https://a0.muscache.com/im/pictures/ec411bac-6...
# 1342096     https://a0.muscache.com/im/pictures/101453837/...
# 6291270     https://a0.muscache.com/im/pictures/79362185/d...
# 9804370     https://a0.muscache.com/im/pictures/2ed03542-a...
# 19306       https://a0.muscache.com/im/pictures/7e0e9bdf-b...
# 25603772    https://a0.muscache.com/im/pictures/4328d573-9...
# 12817885    https://a0.muscache.com/im/pictures/e86d35d9-3...
# 3593610     https://a0.muscache.com/im/pictures/908407ab-5...
# 11645238    https://a0.muscache.com/im/pictures/9241e23b-7...
# 26055995    https://a0.muscache.com/im/pictures/bad4e23a-2...
# 328697      https://a0.muscache.com/im/pictures/13669870/9...
#
#                                          listing.picture_urls  \
# listing.id
# 12431613    [https://a0.muscache.com/im/pictures/a607defd-...
# 6697074     [https://a0.muscache.com/im/pictures/ccd1bf78-...
# 20682202    [https://a0.muscache.com/im/pictures/c393711d-...
# 26612229    [https://a0.muscache.com/im/pictures/7017d6d9-...
# 5654383     [https://a0.muscache.com/im/pictures/104585129...
# 33082947    [https://a0.muscache.com/im/pictures/b6e9fa62-...
# 20742140    [https://a0.muscache.com/im/pictures/290c7840-...
# 32326753    [https://a0.muscache.com/im/pictures/3fab80a8-...
# 23571603    [https://a0.muscache.com/im/pictures/e142f73b-...
# 15542883    [https://a0.muscache.com/im/pictures/868557e5-...
# 1070274     [https://a0.muscache.com/im/pictures/16090139/...
# 416129      [https://a0.muscache.com/im/pictures/5000794/3...
# 14994130    [https://a0.muscache.com/im/pictures/bef3e90b-...
# 1475524     [https://a0.muscache.com/im/pictures/36998367/...
# 1076722     [https://a0.muscache.com/im/pictures/39213752/...
# 31253885    [https://a0.muscache.com/im/pictures/8e1c4cac-...
# 9825542     [https://a0.muscache.com/im/pictures/71977d16-...
# 31728633    [https://a0.muscache.com/im/pictures/4ef5c58b-...
# 29919515    [https://a0.muscache.com/im/pictures/c15e1142-...
# 37481238    [https://a0.muscache.com/im/pictures/c4b8499c-...
# 13592356    [https://a0.muscache.com/im/pictures/f7a02df6-...
# 31728633    [https://a0.muscache.com/im/pictures/4ef5c58b-...
# 37763841    [https://a0.muscache.com/im/pictures/8d8b680d-...
# 7397        [https://a0.muscache.com/im/pictures/67928287/...
# 20233344    [https://a0.muscache.com/im/pictures/76ec8cf0-...
# 33717543    [https://a0.muscache.com/im/pictures/79b4ab49-...
# 3777799     [https://a0.muscache.com/im/pictures/47538604/...
# 31708383    [https://a0.muscache.com/im/pictures/b3b3cf42-...
# 31253885    [https://a0.muscache.com/im/pictures/8e1c4cac-...
# 6792978     [https://a0.muscache.com/im/pictures/0a12288d-...
# ...                                                       ...
# 37246141    [https://a0.muscache.com/im/pictures/4170bc68-...
# 34298068    [https://a0.muscache.com/im/pictures/c5766788-...
# 13780542    [https://a0.muscache.com/im/pictures/8c666146-...
# 29043237    [https://a0.muscache.com/im/pictures/4aba0163-...
# 34197580    [https://a0.muscache.com/im/pictures/6a76aedd-...
# 30468415    [https://a0.muscache.com/im/pictures/07b1d84a-...
# 16000388    [https://a0.muscache.com/im/pictures/39e2407d-...
# 505610      [https://a0.muscache.com/im/pictures/12907872/...
# 29239705    [https://a0.muscache.com/im/pictures/916c2bca-...
# 22596412    [https://a0.muscache.com/im/pictures/52a8fb6d-...
# 9617895     [https://a0.muscache.com/im/pictures/b0595cb6-...
# 2391541     [https://a0.muscache.com/im/pictures/32667010/...
# 9617895     [https://a0.muscache.com/im/pictures/b0595cb6-...
# 2391541     [https://a0.muscache.com/im/pictures/32667010/...
# 2024381     [https://a0.muscache.com/im/pictures/27774125/...
# 27242148    [https://a0.muscache.com/im/pictures/e3a60d30-...
# 36341901    [https://a0.muscache.com/im/pictures/ddfc31c7-...
# 21445919    [https://a0.muscache.com/im/pictures/23746f5e-...
# 532742      [https://a0.muscache.com/im/pictures/ef9e906b-...
# 36331096    [https://a0.muscache.com/im/pictures/ec411bac-...
# 1342096     [https://a0.muscache.com/im/pictures/101453837...
# 6291270     [https://a0.muscache.com/im/pictures/79362185/...
# 9804370     [https://a0.muscache.com/im/pictures/2ed03542-...
# 19306       [https://a0.muscache.com/im/pictures/7e0e9bdf-...
# 25603772    [https://a0.muscache.com/im/pictures/4328d573-...
# 12817885    [https://a0.muscache.com/im/pictures/e86d35d9-...
# 3593610     [https://a0.muscache.com/im/pictures/908407ab-...
# 11645238    [https://a0.muscache.com/im/pictures/9241e23b-...
# 26055995    [https://a0.muscache.com/im/pictures/bad4e23a-...
# 328697      [https://a0.muscache.com/im/pictures/13669870/...
#
#                                  listing.preview_amenities  \
# listing.id
# 12431613                          Wi-Fi,Cuisine,Lave-linge
# 6697074                           Wi-Fi,Cuisine,Lave-linge
# 20682202    Hôte : une entreprise,Wi-Fi,Cuisine,Lave-linge
# 26612229                          Wi-Fi,Cuisine,Lave-linge
# 5654383                           Wi-Fi,Cuisine,Lave-linge
# 33082947                                     Wi-Fi,Cuisine
# 20742140               Hôte : une entreprise,Wi-Fi,Cuisine
# 32326753                          Wi-Fi,Cuisine,Lave-linge
# 23571603                          Wi-Fi,Cuisine,Lave-linge
# 15542883                          Wi-Fi,Cuisine,Lave-linge
# 1070274           Wi-Fi,Cuisine,Parking gratuit,Lave-linge
# 416129                            Wi-Fi,Cuisine,Lave-linge
# 14994130                                     Wi-Fi,Cuisine
# 1475524                                              Wi-Fi
# 1076722                           Wi-Fi,Cuisine,Lave-linge
# 31253885                          Wi-Fi,Cuisine,Lave-linge
# 9825542     Hôte : une entreprise,Wi-Fi,Cuisine,Lave-linge
# 31728633                                     Wi-Fi,Cuisine
# 29919515                          Wi-Fi,Cuisine,Lave-linge
# 37481238                          Wi-Fi,Cuisine,Lave-linge
# 13592356                                     Wi-Fi,Cuisine
# 31728633                                     Wi-Fi,Cuisine
# 37763841                          Wi-Fi,Cuisine,Lave-linge
# 7397                              Wi-Fi,Cuisine,Lave-linge
# 20233344          Wi-Fi,Cuisine,Parking gratuit,Lave-linge
# 33717543          Wi-Fi,Cuisine,Parking gratuit,Lave-linge
# 3777799                           Wi-Fi,Cuisine,Lave-linge
# 31708383
# 31253885                          Wi-Fi,Cuisine,Lave-linge
# 6792978                           Wi-Fi,Cuisine,Lave-linge
# ...                                                    ...
# 37246141                          Wi-Fi,Cuisine,Lave-linge
# 34298068                                             Wi-Fi
# 13780542    Hôte : une entreprise,Wi-Fi,Cuisine,Lave-linge
# 29043237                          Wi-Fi,Cuisine,Lave-linge
# 34197580                          Wi-Fi,Cuisine,Lave-linge
# 30468415                          Wi-Fi,Cuisine,Lave-linge
# 16000388                          Wi-Fi,Cuisine,Lave-linge
# 505610                            Wi-Fi,Cuisine,Lave-linge
# 29239705                          Wi-Fi,Cuisine,Lave-linge
# 22596412                          Wi-Fi,Cuisine,Lave-linge
# 9617895                           Wi-Fi,Cuisine,Lave-linge
# 2391541                           Wi-Fi,Cuisine,Lave-linge
# 9617895                           Wi-Fi,Cuisine,Lave-linge
# 2391541                           Wi-Fi,Cuisine,Lave-linge
# 2024381                           Wi-Fi,Cuisine,Lave-linge
# 27242148                          Wi-Fi,Cuisine,Lave-linge
# 36341901                          Wi-Fi,Cuisine,Lave-linge
# 21445919                          Wi-Fi,Cuisine,Lave-linge
# 532742                            Wi-Fi,Cuisine,Lave-linge
# 36331096                          Wi-Fi,Cuisine,Lave-linge
# 1342096                Hôte : une entreprise,Wi-Fi,Cuisine
# 6291270                           Wi-Fi,Cuisine,Lave-linge
# 9804370                           Wi-Fi,Cuisine,Lave-linge
# 19306                             Wi-Fi,Cuisine,Lave-linge
# 25603772                          Wi-Fi,Cuisine,Lave-linge
# 12817885                          Wi-Fi,Cuisine,Lave-linge
# 3593610                           Wi-Fi,Cuisine,Lave-linge
# 11645238                          Wi-Fi,Cuisine,Lave-linge
# 26055995                          Wi-Fi,Cuisine,Lave-linge
# 328697      Hôte : une entreprise,Wi-Fi,Cuisine,Lave-linge
#
#                                 listing.preview_amenity_names  \
# listing.id
# 12431613                         [Wi-Fi, Cuisine, Lave-linge]
# 6697074                          [Wi-Fi, Cuisine, Lave-linge]
# 20682202    [Hôte : une entreprise, Wi-Fi, Cuisine, Lave-l...
# 26612229                         [Wi-Fi, Cuisine, Lave-linge]
# 5654383                          [Wi-Fi, Cuisine, Lave-linge]
# 33082947                                     [Wi-Fi, Cuisine]
# 20742140              [Hôte : une entreprise, Wi-Fi, Cuisine]
# 32326753                         [Wi-Fi, Cuisine, Lave-linge]
# 23571603                         [Wi-Fi, Cuisine, Lave-linge]
# 15542883                         [Wi-Fi, Cuisine, Lave-linge]
# 1070274         [Wi-Fi, Cuisine, Parking gratuit, Lave-linge]
# 416129                           [Wi-Fi, Cuisine, Lave-linge]
# 14994130                                     [Wi-Fi, Cuisine]
# 1475524                                               [Wi-Fi]
# 1076722                          [Wi-Fi, Cuisine, Lave-linge]
# 31253885                         [Wi-Fi, Cuisine, Lave-linge]
# 9825542     [Hôte : une entreprise, Wi-Fi, Cuisine, Lave-l...
# 31728633                                     [Wi-Fi, Cuisine]
# 29919515                         [Wi-Fi, Cuisine, Lave-linge]
# 37481238                         [Wi-Fi, Cuisine, Lave-linge]
# 13592356                                     [Wi-Fi, Cuisine]
# 31728633                                     [Wi-Fi, Cuisine]
# 37763841                         [Wi-Fi, Cuisine, Lave-linge]
# 7397                             [Wi-Fi, Cuisine, Lave-linge]
# 20233344        [Wi-Fi, Cuisine, Parking gratuit, Lave-linge]
# 33717543        [Wi-Fi, Cuisine, Parking gratuit, Lave-linge]
# 3777799                          [Wi-Fi, Cuisine, Lave-linge]
# 31708383                                                   []
# 31253885                         [Wi-Fi, Cuisine, Lave-linge]
# 6792978                          [Wi-Fi, Cuisine, Lave-linge]
# ...                                                       ...
# 37246141                         [Wi-Fi, Cuisine, Lave-linge]
# 34298068                                              [Wi-Fi]
# 13780542    [Hôte : une entreprise, Wi-Fi, Cuisine, Lave-l...
# 29043237                         [Wi-Fi, Cuisine, Lave-linge]
# 34197580                         [Wi-Fi, Cuisine, Lave-linge]
# 30468415                         [Wi-Fi, Cuisine, Lave-linge]
# 16000388                         [Wi-Fi, Cuisine, Lave-linge]
# 505610                           [Wi-Fi, Cuisine, Lave-linge]
# 29239705                         [Wi-Fi, Cuisine, Lave-linge]
# 22596412                         [Wi-Fi, Cuisine, Lave-linge]
# 9617895                          [Wi-Fi, Cuisine, Lave-linge]
# 2391541                          [Wi-Fi, Cuisine, Lave-linge]
# 9617895                          [Wi-Fi, Cuisine, Lave-linge]
# 2391541                          [Wi-Fi, Cuisine, Lave-linge]
# 2024381                          [Wi-Fi, Cuisine, Lave-linge]
# 27242148                         [Wi-Fi, Cuisine, Lave-linge]
# 36341901                         [Wi-Fi, Cuisine, Lave-linge]
# 21445919                         [Wi-Fi, Cuisine, Lave-linge]
# 532742                           [Wi-Fi, Cuisine, Lave-linge]
# 36331096                         [Wi-Fi, Cuisine, Lave-linge]
# 1342096               [Hôte : une entreprise, Wi-Fi, Cuisine]
# 6291270                          [Wi-Fi, Cuisine, Lave-linge]
# 9804370                          [Wi-Fi, Cuisine, Lave-linge]
# 19306                            [Wi-Fi, Cuisine, Lave-linge]
# 25603772                         [Wi-Fi, Cuisine, Lave-linge]
# 12817885                         [Wi-Fi, Cuisine, Lave-linge]
# 3593610                          [Wi-Fi, Cuisine, Lave-linge]
# 11645238                         [Wi-Fi, Cuisine, Lave-linge]
# 26055995                         [Wi-Fi, Cuisine, Lave-linge]
# 328697      [Hôte : une entreprise, Wi-Fi, Cuisine, Lave-l...
#
#                         listing.room_and_property_type  \
# listing.id
# 12431613                               Logement entier
# 6697074                                Logement entier
# 20682202                               Logement entier
# 26612229                               Logement entier
# 5654383                                Logement entier
# 33082947    Appartement avec services hôteliers entier
# 20742140                               Logement entier
# 32326753                               Logement entier
# 23571603                               Logement entier
# 15542883                               Logement entier
# 1070274                                Logement entier
# 416129                                 Logement entier
# 14994130                               Logement entier
# 1475524                                Logement entier
# 1076722                Appartement en résidence entier
# 31253885                               Logement entier
# 9825542                                Logement entier
# 31728633                               Logement entier
# 29919515                               Logement entier
# 37481238                               Logement entier
# 13592356                               Logement entier
# 31728633                               Logement entier
# 37763841                               Logement entier
# 7397                                   Logement entier
# 20233344             Chambre privée dans : appartement
# 33717543               Appartement en résidence entier
# 3777799                                Logement entier
# 31708383                                   Micromaison
# 31253885                               Logement entier
# 6792978                                Logement entier
# ...                                                ...
# 37246141               Appartement en résidence entier
# 34298068                  Chambre privée dans : bateau
# 13780542                               Logement entier
# 29043237                               Logement entier
# 34197580                               Logement entier
# 30468415                               Logement entier
# 16000388                               Logement entier
# 505610                                 Logement entier
# 29239705                               Logement entier
# 22596412                               Logement entier
# 9617895                                    Loft entier
# 2391541                                Logement entier
# 9617895                                    Loft entier
# 2391541                                Logement entier
# 2024381                                Logement entier
# 27242148                               Logement entier
# 36341901                               Logement entier
# 21445919                               Logement entier
# 532742                                 Logement entier
# 36331096                               Logement entier
# 1342096                                Logement entier
# 6291270                                Logement entier
# 9804370                                Logement entier
# 19306                                  Logement entier
# 25603772                               Logement entier
# 12817885                               Logement entier
# 3593610                                Logement entier
# 11645238                               Logement entier
# 26055995                               Logement entier
# 328697                                 Logement entier
#
#             pricing_quote.can_instant_book  \
# listing.id
# 12431613                              True
# 6697074                              False
# 20682202                              True
# 26612229                             False
# 5654383                              False
# 33082947                              True
# 20742140                              True
# 32326753                              True
# 23571603                              True
# 15542883                             False
# 1070274                               True
# 416129                               False
# 14994130                              True
# 1475524                               True
# 1076722                               True
# 31253885                             False
# 9825542                               True
# 31728633                              True
# 29919515                              True
# 37481238                              True
# 13592356                              True
# 31728633                              True
# 37763841                              True
# 7397                                 False
# 20233344                              True
# 33717543                              True
# 3777799                               True
# 31708383                              True
# 31253885                             False
# 6792978                               True
# ...                                    ...
# 37246141                              True
# 34298068                              True
# 13780542                             False
# 29043237                             False
# 34197580                              True
# 30468415                             False
# 16000388                             False
# 505610                               False
# 29239705                             False
# 22596412                              True
# 9617895                               True
# 2391541                               True
# 9617895                               True
# 2391541                               True
# 2024381                              False
# 27242148                              True
# 36341901                              True
# 21445919                             False
# 532742                                True
# 36331096                             False
# 1342096                               True
# 6291270                              False
# 9804370                              False
# 19306                                 True
# 25603772                             False
# 12817885                              True
# 3593610                               True
# 11645238                             False
# 26055995                              True
# 328697                               False
#
#            pricing_quote.price.total.amount_formatted  \
# listing.id
# 12431613                                       1 095€
# 6697074                                          789€
# 20682202                                       1 182€
# 26612229                                         828€
# 5654383                                        1 075€
# 33082947                                         881€
# 20742140                                         858€
# 32326753                                       1 052€
# 23571603                                       1 287€
# 15542883                                       1 635€
# 1070274                                          939€
# 416129                                         1 579€
# 14994130                                         695€
# 1475524                                          695€
# 1076722                                        1 070€
# 31253885                                         767€
# 9825542                                          981€
# 31728633                                         837€
# 29919515                                         482€
# 37481238                                         661€
# 13592356                                         743€
# 31728633                                         837€
# 37763841                                       1 110€
# 7397                                           1 579€
# 20233344                                         521€
# 33717543                                         376€
# 3777799                                          707€
# 31708383                                         637€
# 31253885                                         767€
# 6792978                                          770€
# ...                                               ...
# 37246141                                       1 087€
# 34298068                                         962€
# 13780542                                       1 275€
# 29043237                                       1 100€
# 34197580                                         955€
# 30468415                                       1 214€
# 16000388                                         906€
# 505610                                         1 048€
# 29239705                                         901€
# 22596412                                       1 218€
# 9617895                                        1 501€
# 2391541                                        1 099€
# 9617895                                        1 501€
# 2391541                                        1 099€
# 2024381                                        1 529€
# 27242148                                       1 134€
# 36341901                                       1 113€
# 21445919                                         889€
# 532742                                         1 404€
# 36331096                                       1 214€
# 1342096                                          895€
# 6291270                                          662€
# 9804370                                          912€
# 19306                                          1 506€
# 25603772                                       1 003€
# 12817885                                         649€
# 3593610                                        1 509€
# 11645238                                       1 282€
# 26055995                                       1 003€
# 328697                                         1 365€
#
#                           pricing_quote.price_drop_disclaimer  \
# listing.id
# 12431613                                                  NaN
# 6697074                                                   NaN
# 20682202                                                  NaN
# 26612229                                                  NaN
# 5654383     Le prix à la nuit de ce logement est réduit de...
# 33082947    Le prix à la nuit de ce logement est réduit de...
# 20742140                                                  NaN
# 32326753                                                  NaN
# 23571603                                                  NaN
# 15542883                                                  NaN
# 1070274                                                   NaN
# 416129      Le prix à la nuit de ce logement est réduit de...
# 14994130                                                  NaN
# 1475524     Le prix à la nuit de ce logement est réduit de...
# 1076722                                                   NaN
# 31253885                                                  NaN
# 9825542                                                   NaN
# 31728633                                                  NaN
# 29919515                                                  NaN
# 37481238    Le prix à la nuit de ce logement est réduit de...
# 13592356                                                  NaN
# 31728633                                                  NaN
# 37763841                                                  NaN
# 7397                                                      NaN
# 20233344                                                  NaN
# 33717543    Le prix à la nuit de ce logement est réduit de...
# 3777799                                                   NaN
# 31708383    Le prix à la nuit de ce logement est réduit de...
# 31253885                                                  NaN
# 6792978                                                   NaN
# ...                                                       ...
# 37246141                                                  NaN
# 34298068    Le prix à la nuit de ce logement est réduit de...
# 13780542                                                  NaN
# 29043237                                                  NaN
# 34197580                                                  NaN
# 30468415                                                  NaN
# 16000388    Le prix à la nuit de ce logement est réduit de...
# 505610      Le prix à la nuit de ce logement est réduit de...
# 29239705                                                  NaN
# 22596412                                                  NaN
# 9617895     Le prix à la nuit de ce logement est réduit de...
# 2391541                                                   NaN
# 9617895     Le prix à la nuit de ce logement est réduit de...
# 2391541                                                   NaN
# 2024381     Le prix à la nuit de ce logement est réduit de...
# 27242148                                                  NaN
# 36341901                                                  NaN
# 21445919                                                  NaN
# 532742                                                    NaN
# 36331096                                                  NaN
# 1342096     Le prix à la nuit de ce logement est réduit de...
# 6291270                                                   NaN
# 9804370                                                   NaN
# 19306                                                     NaN
# 25603772                                                  NaN
# 12817885                                                  NaN
# 3593610                                                   NaN
# 11645238                                                  NaN
# 26055995                                                  NaN
# 328697                                                    NaN
#
#            pricing_quote.rate.amount_formatted
# listing.id
# 12431613                                  110€
# 6697074                                    79€
# 20682202                                  119€
# 26612229                                   83€
# 5654383                                   108€
# 33082947                                   89€
# 20742140                                   86€
# 32326753                                  106€
# 23571603                                  129€
# 15542883                                  164€
# 1070274                                    94€
# 416129                                    158€
# 14994130                                   70€
# 1475524                                    70€
# 1076722                                   107€
# 31253885                                   77€
# 9825542                                    99€
# 31728633                                   84€
# 29919515                                   49€
# 37481238                                   67€
# 13592356                                   75€
# 31728633                                   84€
# 37763841                                  111€
# 7397                                      158€
# 20233344                                   53€
# 33717543                                   38€
# 3777799                                    71€
# 31708383                                   64€
# 31253885                                   77€
# 6792978                                    77€
# ...                                        ...
# 37246141                                  109€
# 34298068                                   97€
# 13780542                                  128€
# 29043237                                  110€
# 34197580                                   96€
# 30468415                                  122€
# 16000388                                   91€
# 505610                                    105€
# 29239705                                   91€
# 22596412                                  122€
# 9617895                                   151€
# 2391541                                   110€
# 9617895                                   151€
# 2391541                                   110€
# 2024381                                   153€
# 27242148                                  114€
# 36341901                                  112€
# 21445919                                   89€
# 532742                                    141€
# 36331096                                  122€
# 1342096                                    90€
# 6291270                                    67€
# 9804370                                    92€
# 19306                                     151€
# 25603772                                  101€
# 12817885                                   65€
# 3593610                                   151€
# 11645238                                  129€
# 26055995                                  101€
# 328697                                    137€
#
# [288 rows x 20 columns]
